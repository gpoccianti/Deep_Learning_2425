# %% [markdown]
# # DeepONet Tutorial in PyTorch
#
# This notebook is a PyTorch reimplementation of a simple 1D DeepONet originally written in JAX/Equinox.
# It learns the antiderivative operator from pairs $(u(x), x)$ to $\int_0^x u(s) ds$ using the aligned dataset from DeepXDE.
#
# **What changes vs JAX version**
# - Uses `torch.nn` modules for the branch/trunk MLPs and a learnable scalar bias.
# - Uses `torch.optim.Adam` with a standard manual training loop.
# - Replaces `jax.vmap` with batched tensor operations.
# - Keeps plots and evaluation identical where possible.

# %% [markdown]
# A DeepONet is a deep learning architecture to evaluate a *nonlinear operator*
# applied to a discretized input field/function at an arbitrary query point. This
# can, for instance, be used to learn solutions to a family of parametric PDEs
# which can then be queried at arbitrary points in space (and time).
#
# Examples of operator mappings:
#
# * From initial condition to solution field at a later time
# * From the parameter field (e.g. space-dependent diffusion coefficient) to the
#   solution field
#
# The DeepONet does not return the full output field, but allows us to query it at
# arbitrary points.
#
# Following the tutorial of
# [DeepXDE](https://deepxde.readthedocs.io/en/latest/demos/operator/antiderivative_aligned.html),
# this video is concered with **learning the 1d antiderivative operator**, defined by the ODE
#
# $$
# \begin{cases}
# \frac{d v}{d x} &= u(x) \quad & x \in [0, 1]
# \\
# v(0) &= 0
# \end{cases}
# $$
#
# For this, we discretize the domain $\Omega = [0, 1]$ into $m=100$ degrees of
# freedom at which we evaluate $u(x)$. Then, the DeepONet $G_\theta$ takes this
# $100$-dimensional vector and a one-dimensional query coordinate to evaluate
# $v(x)$ at this query point.
#
# $$
# \begin{aligned}
# G_\theta : \mathbb{R}^m \times \mathbb{R}^1 \mapsto \mathbb{R}
# \end{aligned}
# $$

# %% [markdown]
# ![deeponet_architecture](deeponet_architecture.png)

# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
#from tqdm.autonotebook import tqdm
from tqdm import tqdm

# Prefer CUDA if available, else MPS (Apple Silicon), else CPU
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

device
# Out:
# device(type='cuda')

# %%
# Dataset courtesy of DeepXDE (Lu et al.).
# Original JAX notebook downloaded from ETH Zurich course materials.
# We'll fetch the same training/test sets used there.
#!wget -q -O antiderivative_aligned_train.npz https://github.com/mroberto166/CAMLab-DLSCTutorials/raw/main/antiderivative_aligned_train.npz
#!wget -q -O antiderivative_aligned_test.npz  https://github.com/mroberto166/CAMLab-DLSCTutorials/raw/main/antiderivative_aligned_test.npz

import numpy as np

# Load all splits
train_npz = np.load("antiderivative_aligned_train.npz", allow_pickle=True)
val_npz   = np.load("antiderivative_aligned_val.npz", allow_pickle=True)
test_npz  = np.load("antiderivative_aligned_test.npz", allow_pickle=True)

# --- Training set ---
branch_inputs_train = train_npz["X"][0]   # (N_train, in_size_branch)
trunk_inputs_train  = train_npz["X"][1]   # (N_train, N_grid, 1)
outputs_train       = train_npz["y"]      # (N_train, N_grid, 1)

# --- Validation set ---
branch_inputs_val = val_npz["X"][0]       # (N_val, in_size_branch)
trunk_inputs_val  = val_npz["X"][1]       # (N_val, N_grid, 1)
outputs_val       = val_npz["y"]          # (N_val, N_grid, 1)

# --- Test set ---
branch_inputs_test = test_npz["X"][0]     # (N_test, in_size_branch)
trunk_inputs_test  = test_npz["X"][1]     # (N_test, N_grid, 1)
outputs_test       = test_npz["y"]        # (N_test, N_grid, 1)

# Check shapes
print("Train:", branch_inputs_train.shape, trunk_inputs_train.shape, outputs_train.shape)
print("Val:  ", branch_inputs_val.shape,   trunk_inputs_val.shape,   outputs_val.shape)
print("Test: ", branch_inputs_test.shape,  trunk_inputs_test.shape,  outputs_test.shape)
# Out:
# Train: (1050, 1000) (1000, 1) (1050, 1000)
# Val:   (150, 1000) (1000, 1) (150, 1000)
# Test:  (300, 1000) (1000, 1) (300, 1000)

# %%
f_idx=0 #index of the function to plot
plt.plot(trunk_inputs_train[:, 0], branch_inputs_train[f_idx, :], label="input u(x)")
plt.plot(trunk_inputs_train[:, 0], outputs_train[f_idx, :], label="∫ u ds (gt)")
plt.grid()
plt.legend()
plt.title("Sample training pair (aligned grid)")
plt.show()

# %%
class MLP(nn.Module):
    def __init__(self, in_size, out_size, width_size, depth, activation=nn.ReLU, dropout=0.0):
        super().__init__()
        layers = []
        last = in_size
        for _ in range(depth):
            layers.append(nn.Linear(last, width_size))
            layers.append(activation())
            if dropout > 0:
                layers.append(nn.Dropout(dropout))  # Dropout
            last = width_size
        layers.append(nn.Linear(last, out_size))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)


class DeepONet1dSep(nn.Module):
    def __init__(
        self,
        in_size_branch: int,
        interact_size: int,
        branch_width: int = 40,
        branch_depth: int = 2,
        branch_activation: nn.Module = nn.ReLU,
        branch_dropout: float = 0.0,       # <--- aggiunto
        trunk_input_dim: int = 1,
        trunk_width: int = 40,
        trunk_depth: int = 2,
        trunk_activation: nn.Module = nn.Tanh,
        trunk_dropout: float = 0.0,        # <--- aggiunto
    ):
        super().__init__()
        self.branch_net = MLP(
            in_size=in_size_branch,
            out_size=interact_size,
            width_size=branch_width,
            depth=branch_depth,
            activation=branch_activation,
            dropout=branch_dropout
        )
        self.trunk_net = MLP(
            in_size=trunk_input_dim,
            out_size=interact_size,
            width_size=trunk_width,
            depth=trunk_depth,
            activation=trunk_activation,
            dropout=trunk_dropout
        )
        self.bias = nn.Parameter(torch.zeros(1))


    def forward(self, x_branch, x_trunk):
        """
        x_branch: (B, P) or (P,)
        x_trunk:  (N,1) or (B, N) or (B, N, 1)
        returns:  (B, N, 1) or (N, 1) if single-sample
        """
        single_sample = False
        if x_branch.dim() == 1:
            x_branch = x_branch.unsqueeze(0)  # (1, P)
            single_sample = True

        # Normalize x_trunk to (B, N, 1)
        if x_trunk.dim() == 1:
            x_trunk = x_trunk.unsqueeze(-1)                # (N,) -> (N,1)
        if x_trunk.dim() == 2:
            if x_trunk.size(-1) != 1:                      # (B,N) -> (B,N,1)
                x_trunk = x_trunk.unsqueeze(-1)
            else:                                          # (N,1) -> (B,N,1)
                x_trunk = x_trunk.unsqueeze(0).expand(x_branch.size(0), -1, -1)
        elif x_trunk.dim() == 3 and x_trunk.size(0) == 1 and x_branch.size(0) > 1:
            x_trunk = x_trunk.expand(x_branch.size(0), -1, -1)

        B, N, _ = x_trunk.shape
        bfeat = self.branch_net(x_branch)                        # (B, P')
        tfeat = self.trunk_net(x_trunk.reshape(B * N, -1))       # (B*N, P')
        tfeat = tfeat.view(B, N, -1)                             # (B, N, P')
        out = (bfeat.unsqueeze(1) * tfeat).sum(dim=-1, keepdim=True) + self.bias.view(1, 1, 1)
        if single_sample:
            out = out.squeeze(0)  # (N,1)
        return out

# %% [markdown]
# ## Hyperparameter optimization

# %%
#Version without validation
"""
import torch
import optuna
import torch.optim as optim
from torch import nn
from tqdm import tqdm  # Import tqdm for progress bar

# Ensure your training and testing data are loaded here
# Example (adjust as needed based on your dataset):
Xb_train = torch.tensor(branch_inputs_train, dtype=torch.float32, device=device)  # (N_train, in_size_branch)
Xt_train = torch.tensor(trunk_inputs_train,  dtype=torch.float32, device=device)  # (N_train, N_grid, 1)
Y_train = torch.tensor(outputs_train, dtype=torch.float32, device=device)  # (N_train, N_grid, 1)

Xb_test = torch.tensor(branch_inputs_test, dtype=torch.float32, device=device)  # (N_test, in_size_branch)
Xt_test = torch.tensor(trunk_inputs_test,  dtype=torch.float32, device=device)  # (N_test, N_grid, 1)
Y_test = torch.tensor(outputs_test, dtype=torch.float32, device=device)  # (N_test, N_grid, 1)

# Ensure Y_train and Y_test have the shape (B, N, 1)
if Y_train.dim() == 2:
    Y_train = Y_train.unsqueeze(-1)  # (N_train, N_grid) -> (N_train, N_grid, 1)
if Y_test.dim() == 2:
    Y_test = Y_test.unsqueeze(-1)  # (N_test, N_grid) -> (N_test, N_grid, 1)

# Define the objective function for Optuna's optimization
def objective(trial: optuna.Trial):
    # Altri iperparametri già presenti...
    dropout_branch = trial.suggest_float("dropout_branch", 0.0, 0.5)
    dropout_trunk  = trial.suggest_float("dropout_trunk", 0.0, 0.5)

    # Model setup
    model = DeepONet1dSep(
        in_size_branch=Xb_train.shape[1],
        interact_size=trial.suggest_int("interact_size", 5, 100, step=30),
        branch_width=trial.suggest_int("branch_width", 10, 200, step=30),
        branch_depth=trial.suggest_int("branch_depth", 1, 5),
        branch_activation=trial.suggest_categorical("branch_activation", [nn.ReLU, nn.Tanh, nn.GELU]),
        branch_dropout=dropout_branch,  # <--- aggiunto
        trunk_input_dim=1,
        trunk_width=trial.suggest_int("trunk_width", 10, 200, step=30),
        trunk_depth=trial.suggest_int("trunk_depth", 1, 5),
        trunk_activation=trial.suggest_categorical("trunk_activation", [nn.ReLU, nn.Tanh, nn.GELU]),
        trunk_dropout=dropout_trunk     # <--- aggiunto
    ).to(device)

    # Ottimizzatore con L2
    optimizer = optim.Adam(
        model.parameters(),
        lr=trial.suggest_loguniform("learning_rate", 1e-5, 1e-2),
        weight_decay=trial.suggest_loguniform("l2_reg_strength", 1e-5, 1e-2)
    )

    # Training loop
    model.train()
    num_epochs = 10
    for epoch in range(num_epochs):
        optimizer.zero_grad()
        outputs = model(Xb_train, Xt_train)
        loss = torch.mean((outputs - Y_train)**2)
        loss.backward()
        optimizer.step()

    # Validation MSE
    model.eval()
    with torch.no_grad():
        Y_pred = model(Xb_test, Xt_test)
        mse = torch.mean((Y_pred - Y_test)**2).item()

    return mse

# Create Optuna study and optimize the objective function with a tqdm progress bar for the entire optimization process
study = optuna.create_study(direction="minimize")

# Use tqdm for overall progress bar across all trials
n_trials = 5000
with tqdm(total=n_trials, desc="Overall Optimization Progress", position=0, leave=True) as pbar:
    def tqdm_callback(study, trial):
        pbar.update(1)  # Update the progress bar after each trial

    # You can resume optimization if there is a stored study
    study.optimize(objective, n_trials=n_trials, callbacks=[tqdm_callback])

# Save the best parameters found
best_params = study.best_params
print(f"Best parameters: {best_params}")

# Save best parameters to a file
import pickle
with open("best_params.pkl", "wb") as f:
    pickle.dump(best_params, f)
"""
# Out:
# '\nimport torch\nimport optuna\nimport torch.optim as optim\nfrom torch import nn\nfrom tqdm import tqdm  # Import tqdm for progress bar\n\n# Ensure your training and testing data are loaded here\n# Example (adjust as needed based on your dataset):\nXb_train = torch.tensor(branch_inputs_train, dtype=torch.float32, device=device)  # (N_train, in_size_branch)\nXt_train = torch.tensor(trunk_inputs_train,  dtype=torch.float32, device=device)  # (N_train, N_grid, 1)\nY_train = torch.tensor(outputs_train, dtype=torch.float32, device=device)  # (N_train, N_grid, 1)\n\nXb_test = torch.tensor(branch_inputs_test, dtype=torch.float32, device=device)  # (N_test, in_size_branch)\nXt_test = torch.tensor(trunk_inputs_test,  dtype=torch.float32, device=device)  # (N_test, N_grid, 1)\nY_test = torch.tensor(outputs_test, dtype=torch.float32, device=device)  # (N_test, N_grid, 1)\n\n# Ensure Y_train and Y_test have the shape (B, N, 1)\nif Y_train.dim() == 2:\n    Y_train = Y_train.unsqueeze(-1)  # (N_train, N_grid) -> (N_train, N_grid, 1)\nif Y_test.dim() == 2:\n    Y_test = Y_test.unsqueeze(-1)  # (N_test, N_grid) -> (N_test, N_grid, 1)\n\n# Define the objective function for Optuna\'s optimization\ndef objective(trial: optuna.Trial):\n    # Altri iperparametri già presenti...\n    dropout_branch = trial.suggest_float("dropout_branch", 0.0, 0.5)\n    dropout_trunk  = trial.suggest_float("dropout_trunk", 0.0, 0.5)\n\n    # Model setup\n    model = DeepONet1dSep(\n        in_size_branch=Xb_train.shape[1],\n        interact_size=trial.suggest_int("interact_size", 5, 100, step=30),\n        branch_width=trial.suggest_int("branch_width", 10, 200, step=30),\n        branch_depth=trial.suggest_int("branch_depth", 1, 5),\n        branch_activation=trial.suggest_categorical("branch_activation", [nn.ReLU, nn.Tanh, nn.GELU]),\n        branch_dropout=dropout_branch,  # <--- aggiunto\n        trunk_input_dim=1,\n        trunk_width=trial.suggest_int("trunk_width", 10, 200, step=30),\n        trunk_depth=trial.suggest_int("trunk_depth", 1, 5),\n        trunk_activation=trial.suggest_categorical("trunk_activation", [nn.ReLU, nn.Tanh, nn.GELU]),\n        trunk_dropout=dropout_trunk     # <--- aggiunto\n    ).to(device)\n\n    # Ottimizzatore con L2\n    optimizer = optim.Adam(\n        model.parameters(),\n        lr=trial.suggest_loguniform("learning_rate", 1e-5, 1e-2),\n        weight_decay=trial.suggest_loguniform("l2_reg_strength", 1e-5, 1e-2)\n    )\n\n    # Training loop\n    model.train()\n    num_epochs = 10\n    for epoch in range(num_epochs):\n        optimizer.zero_grad()\n        outputs = model(Xb_train, Xt_train)\n        loss = torch.mean((outputs - Y_train)**2)\n        loss.backward()\n        optimizer.step()\n\n    # Validation MSE\n    model.eval()\n    with torch.no_grad():\n        Y_pred = model(Xb_test, Xt_test)\n        mse = torch.mean((Y_pred - Y_test)**2).item()\n\n    return mse\n\n# Create Optuna study and optimize the objective function with a tqdm progress bar for the entire optimization process\nstudy = optuna.create_study(direction="minimize")\n\n# Use tqdm for overall progress bar across all trials\nn_trials = 5000\nwith tqdm(total=n_trials, desc="Overall Optimization Progress", position=0, leave=True) as pbar:\n    def tqdm_callback(study, trial):\n        pbar.update(1)  # Update the progress bar after each trial\n\n    # You can resume optimization if there is a stored study\n    study.optimize(objective, n_trials=n_trials, callbacks=[tqdm_callback])\n\n# Save the best parameters found\nbest_params = study.best_params\nprint(f"Best parameters: {best_params}")\n\n# Save best parameters to a file\nimport pickle\nwith open("best_params.pkl", "wb") as f:\n    pickle.dump(best_params, f)\n'

# %% [raw]
# #Version with validation but which prunes everything
# import os
# import torch
# import optuna
# import torch.optim as optim
# from torch import nn
#
# # --- optional: better error traces during debugging (set in your shell ideally) ---
# # os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
#
# # ---------------------------
# # Utilities: checks & split
# # ---------------------------
# def assert_same_first_dim(*tensors):
#     n0 = tensors[0].shape[0]
#     for t in tensors[1:]:
#         assert t.shape[0] == n0, f"Batch mismatch: {n0=} vs {t.shape[0]=}"
#
# def make_train_val_split(Xb, Xt, Y, val_frac=0.15, seed=123):
#     N = Xb.shape[0]
#     n_val = max(1, int(N * val_frac))
#     g = torch.Generator(device=Xb.device if Xb.is_cuda else "cpu").manual_seed(seed)
#     perm = torch.randperm(N, generator=g)
#     val_idx, tr_idx = perm[:n_val], perm[n_val:]
#     return (Xb[tr_idx], Xt[tr_idx], Y[tr_idx],
#             Xb[val_idx], Xt[val_idx], Y[val_idx])
#
# def is_finite_tensor(*ts):
#     return all(torch.isfinite(t).all().item() for t in ts)
#
# # ---------------------------
# # CPU smoke test (1 step)
# # ---------------------------
# def cpu_smoke_test(model_ctor, opt_ctor, xb, xt, y):
#     # take a tiny slice to keep it fast
#     s = min(8, xb.shape[0])
#     xb_s, xt_s, y_s = xb[:s].detach().cpu(), xt[:s].detach().cpu(), y[:s].detach().cpu()
#
#     model_cpu = model_ctor().cpu()
#     opt_cpu = opt_ctor(model_cpu.parameters())
#
#     mse = nn.MSELoss()
#     model_cpu.train()
#     try:
#         with torch.no_grad():
#             # quick sanity on shapes and finiteness
#             assert xb_s.dim() == 2, f"Xb dim expected 2, got {xb_s.dim()}"
#             assert xt_s.dim() == 3, f"Xt dim expected 3, got {xt_s.dim()}"
#             assert y_s.dim() == 3,  f"Y  dim expected 3, got {y_s.dim()}"
#             assert_same_first_dim(xb_s, xt_s, y_s)
#             if not is_finite_tensor(xb_s, xt_s, y_s):
#                 return False
#
#         # forward/backward one step
#         pred = model_cpu(xb_s, xt_s)
#         if not (pred.shape == y_s.shape):
#             return False
#         if not is_finite_tensor(pred):
#             return False
#         loss = mse(pred, y_s)
#         if not torch.isfinite(loss).item():
#             return False
#         opt_cpu.zero_grad(set_to_none=True)
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model_cpu.parameters(), max_norm=1.0)
#         opt_cpu.step()
#         return True
#     except Exception:
#         return False
#
# # ---------------------------
# # Training with early stopping + strict guards
# # ---------------------------
# def train_with_early_stopping(model, optimizer,
#                               Xb_tr, Xt_tr, Y_tr,
#                               Xb_val, Xt_val, Y_val,
#                               max_epochs=200, patience=20, min_delta=0.0,
#                               trial: optuna.Trial = None):
#
#     mse = nn.MSELoss()
#     best_val = float("inf")
#     best_state = None
#     no_improve = 0
#
#     for epoch in range(max_epochs):
#         # --- TRAIN ---
#         model.train()
#         # guards
#         assert_same_first_dim(Xb_tr, Xt_tr, Y_tr)
#         if not is_finite_tensor(Xb_tr, Xt_tr, Y_tr):
#             # invalid data -> prune trial
#             raise optuna.TrialPruned()
#
#         optimizer.zero_grad(set_to_none=True)
#
#         # disable AMP casting to avoid dtype surprises
#         with torch.cuda.amp.autocast(enabled=False):
#             pred = model(Xb_tr, Xt_tr)
#
#         # shape + finite checks
#         if pred.shape != Y_tr.shape or not is_finite_tensor(pred):
#             raise optuna.TrialPruned()
#
#         loss = mse(pred, Y_tr)
#         if not torch.isfinite(loss).item():
#             raise optuna.TrialPruned()
#
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#         optimizer.step()
#
#         # --- VAL ---
#         model.eval()
#         with torch.no_grad():
#             with torch.cuda.amp.autocast(enabled=False):
#                 val_pred = model(Xb_val, Xt_val)
#             if val_pred.shape != Y_val.shape or not is_finite_tensor(val_pred):
#                 raise optuna.TrialPruned()
#             val_mse = mse(val_pred, Y_val).item()
#
#         # report for pruning
#         if trial is not None:
#             trial.report(val_mse, step=epoch)
#             if trial.should_prune():
#                 raise optuna.TrialPruned()
#
#         # early stopping bookkeeping
#         if val_mse + min_delta < best_val:
#             best_val = val_mse
#             best_state = {k: v.detach().clone() for k, v in model.state_dict().items()}
#             no_improve = 0
#         else:
#             no_improve += 1
#             if no_improve >= patience:
#                 break
#
#     if best_state is not None:
#         model.load_state_dict(best_state)
#     return best_val
#
# # ---------------------------
# # Objective (unchanged hypers)
# # ---------------------------
# def objective(trial: optuna.Trial):
#     dropout_branch = trial.suggest_float("dropout_branch", 0.0, 0.5)
#     dropout_trunk  = trial.suggest_float("dropout_trunk", 0.0, 0.5)
#
#     interact_size  = trial.suggest_int("interact_size", 5, 100, step=30)
#     branch_width   = trial.suggest_int("branch_width", 10, 200, step=30)
#     branch_depth   = trial.suggest_int("branch_depth", 1, 5)
#     branch_act     = trial.suggest_categorical("branch_activation", [nn.ReLU, nn.Tanh, nn.GELU])
#
#     trunk_width    = trial.suggest_int("trunk_width", 10, 200, step=30)
#     trunk_depth    = trial.suggest_int("trunk_depth", 1, 5)
#     trunk_act      = trial.suggest_categorical("trunk_activation", [nn.ReLU, nn.Tanh, nn.GELU])
#
#     lr             = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
#     l2             = trial.suggest_loguniform("l2_reg_strength", 1e-5, 1e-2)
#
#     # build ctor so smoke test can create CPU instance
#     def build_model():
#         return DeepONet1dSep(
#             in_size_branch=Xb_train.shape[1],
#             interact_size=interact_size,
#             branch_width=branch_width,
#             branch_depth=branch_depth,
#             branch_activation=branch_act,
#             branch_dropout=dropout_branch,
#             trunk_input_dim=1,
#             trunk_width=trunk_width,
#             trunk_depth=trunk_depth,
#             trunk_activation=trunk_act,
#             trunk_dropout=dropout_trunk
#         )
#
#     def build_opt(params):
#         return optim.Adam(params, lr=lr, weight_decay=l2)
#     # --- CPU smoke test to catch bad configs fast ---
#     ok = cpu_smoke_test(build_model, build_opt, Xb_train, Xt_train, Y_train)
#     if not ok:
#         raise optuna.TrialPruned()
#
#     # --- real model on device ---
#     model = build_model().to(device)
#     optimizer = build_opt(model.parameters())
#
#     # split train/val (deterministic)
#     Xb_tr, Xt_tr, Y_tr, Xb_val, Xt_val, Y_val = make_train_val_split(Xb_train, Xt_train, Y_train, val_frac=0.15, seed=123)
#
#
#     # train with early stopping + guards
#     val_mse = train_with_early_stopping(
#         model, optimizer,
#         Xb_tr, Xt_tr, Y_tr,
#         Xb_val, Xt_val, Y_val,
#         max_epochs=200, patience=20, min_delta=0.0,
#         trial=trial
#     )
#     return val_mse
#
#
# # (keep your study/pruner/progress bar code the same)
#
#
# # ---------------------------
# # Study + optimization (with pruning)
# # ---------------------------
# pruner = optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=5)
# study = optuna.create_study(direction="minimize", pruner=pruner)
#
# n_trials = 5000
# with tqdm(total=n_trials, desc="Overall Optimization Progress", position=0, leave=True) as pbar:
#     def tqdm_callback(study, trial):
#         pbar.update(1)
#     study.optimize(objective, n_trials=n_trials, callbacks=[tqdm_callback], gc_after_trial=True)
#
# best_params = study.best_params
# print(f"[Optuna] Best parameters: {best_params}")
#
# # ---------------------------
# # Final training on full train+val, evaluate on TEST
# # ---------------------------
# # Rebuild best model
# best_model = DeepONet1dSep(
#     in_size_branch=Xb_train.shape[1],
#     interact_size=best_params["interact_size"],
#     branch_width=best_params["branch_width"],
#     branch_depth=best_params["branch_depth"],
#     branch_activation=best_params["branch_activation"],
#     branch_dropout=best_params["dropout_branch"],
#     trunk_input_dim=1,
#     trunk_width=best_params["trunk_width"],
#     trunk_depth=best_params["trunk_depth"],
#     trunk_activation=best_params["trunk_activation"],
#     trunk_dropout=best_params["dropout_trunk"]
# ).to(device)
#
# best_opt = optim.Adam(
#     best_model.parameters(),
#     lr=best_params["learning_rate"],
#     weight_decay=best_params["l2_reg_strength"]
# )
#
# # Merge original train+val (i.e., just use all Xb_train/Xt_train/Y_train)
# _ = train_with_early_stopping(
#     best_model, best_opt,
#     Xb_train, Xt_train, Y_train,   # train on all available training data
#     Xb_train, Xt_train, Y_train,   # dummy 'val' == train to enable same loop; patience will quickly trigger
#     max_epochs=200, patience=20, min_delta=0.0,
#     trial=None
# )
#
# best_model.eval()
# with torch.no_grad():
#     Y_pred_test = best_model(Xb_test, Xt_test)
#     test_mse = torch.mean((Y_pred_test - Y_test)**2).item()
# print(f"[Final] Test MSE with best params: {test_mse:.6f}")
#
# # Save best params
# import pickle
# with open("best_params.pkl", "wb") as f:
#     pickle.dump(best_params, f)

# %% [raw]
# #To delete
# # ===== DEBUG version: Optuna + Early Stopping + Smoke Test =====
# import os, pickle
# import torch
# import optuna
# import torch.optim as optim
# from torch import nn
# from tqdm import tqdm
#
# # ---------------------------
# # DEBUG switches & logging
# # ---------------------------
# DEBUG = True  # <<<< abilita messaggi e eccezioni esplicite
# optuna.logging.set_verbosity(optuna.logging.DEBUG)
#
# # --- optional: better error traces during debugging (set in your shell ideally) ---
# # os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
#
# # ---------------------------
# # Utilities: checks & split
# # ---------------------------
# def assert_same_first_dim(*tensors):
#     n0 = tensors[0].shape[0]
#     for t in tensors[1:]:
#         assert t.shape[0] == n0, f"Batch mismatch: n0={n0} vs {t.shape[0]=}"
#
# def make_train_val_split(Xb, Xt, Y, val_frac=0.15, seed=123):
#     N = Xb.shape[0]
#     n_val = max(1, int(N * val_frac))
#     # usa sempre device di Xb per gli indici
#     g = torch.Generator().manual_seed(seed)
#     perm = torch.randperm(N, generator=g, device=Xb.device)
#     val_idx, tr_idx = perm[:n_val], perm[n_val:]
#     return (Xb[tr_idx], Xt[tr_idx], Y[tr_idx],
#             Xb[val_idx], Xt[val_idx], Y[val_idx])
#
# def is_finite_tensor(*ts):
#     return all(torch.isfinite(t).all().item() for t in ts)
#
# def ensure_shapes(Xb, Xt, Y):
#     """
#     Porta i tensori a:
#       Xb: (N, B)
#       Xt: (N, T, d)  -> se è (N,T), diventa (N,T,1)
#       Y : (N, T, 1)  -> se è (N,T), diventa (N,T,1)
#     """
#     if Xt.dim() == 2:
#         Xt = Xt.unsqueeze(-1)
#     if Y.dim() == 2:
#         Y = Y.unsqueeze(-1)
#     return Xb, Xt, Y
#
# def clean_non_finite_(name, arr):
#     bad = ~torch.isfinite(arr)
#     if bad.any():
#         nbad = bad.sum().item()
#         if DEBUG:
#             print(f"[CLEAN] {name}: replacing {nbad} non-finite values with 0")
#         arr[bad] = 0.0
#
# # ---------------------------
# # CPU smoke test (1 step)
# # ---------------------------
# def cpu_smoke_test(model_ctor, opt_ctor, xb, xt, y):
#     # slice piccolo per velocità
#     s = min(8, xb.shape[0])
#     xb_s, xt_s, y_s = xb[:s].detach().cpu(), xt[:s].detach().cpu(), y[:s].detach().cpu()
#
#     model_cpu = model_ctor().cpu()
#     opt_cpu = opt_ctor(model_cpu.parameters())
#
#     mse = nn.MSELoss()
#     model_cpu.train()
#
#     # log forme attese/real
#     if DEBUG:
#         print(f"[SMOKE] Xb {tuple(xb_s.shape)} (expect 2D), "
#               f"Xt {tuple(xt_s.shape)} (expect 3D), "
#               f"Y {tuple(y_s.shape)} (expect 3D)")
#
#     if xb_s.dim()!=2 or xt_s.dim()!=3 or y_s.dim()!=3:
#         raise RuntimeError(f"[SMOKE] Bad dims: (Xb,Xt,Y)={xb_s.dim(), xt_s.dim(), y_s.dim()}")
#
#     assert_same_first_dim(xb_s, xt_s, y_s)
#
#     if not is_finite_tensor(xb_s, xt_s, y_s):
#         raise RuntimeError("[SMOKE] Non-finite values in inputs")
#
#     with torch.no_grad():
#         pred = model_cpu(xb_s, xt_s)
#
#     if DEBUG:
#         print(f"[SMOKE] pred shape {tuple(pred.shape)}, Y shape {tuple(y_s.shape)}")
#
#     if pred.shape != y_s.shape:
#         raise RuntimeError(f"[SMOKE] Pred/Y shape mismatch: pred={tuple(pred.shape)} vs Y={tuple(y_s.shape)}")
#
#     if not is_finite_tensor(pred):
#         raise RuntimeError("[SMOKE] Non-finite pred")
#
#     # Un passo di backward
#     opt_cpu.zero_grad(set_to_none=True)
#     loss = mse(pred, y_s)
#     if not torch.isfinite(loss).item():
#         raise RuntimeError("[SMOKE] Non-finite loss")
#     loss.backward()
#     torch.nn.utils.clip_grad_norm_(model_cpu.parameters(), max_norm=1.0)
#     opt_cpu.step()
#     return True
#
# # ---------------------------
# # Helper: guardie -> errori in DEBUG, prune in PROD
# # ---------------------------
# def _handle_guard_fail(msg):
#     if DEBUG:
#         raise RuntimeError(msg)
#     else:
#         raise optuna.TrialPruned()
#
# # ---------------------------
# # Training con early stopping + guardie
# # ---------------------------
# def train_with_early_stopping(model, optimizer,
#                               Xb_tr, Xt_tr, Y_tr,
#                               Xb_val, Xt_val, Y_val,
#                               max_epochs=200, patience=20, min_delta=0.0,
#                               trial: optuna.Trial = None):
#
#     mse = nn.MSELoss()
#     best_val = float("inf")
#     best_state = None
#     no_improve = 0
#
#     for epoch in range(max_epochs):
#         # --- TRAIN ---
#         model.train()
#         assert_same_first_dim(Xb_tr, Xt_tr, Y_tr)
#         if not is_finite_tensor(Xb_tr, Xt_tr, Y_tr):
#             _handle_guard_fail("[TRAIN] Non-finite in train data")
#
#         optimizer.zero_grad(set_to_none=True)
#
#         # disabilita AMP per semplicità in debug
#         with torch.cuda.amp.autocast(enabled=False):
#             pred = model(Xb_tr, Xt_tr)
#
#         if pred.shape != Y_tr.shape or not is_finite_tensor(pred):
#             _handle_guard_fail(f"[TRAIN] pred bad: pred={tuple(pred.shape)} vs Y={tuple(Y_tr.shape)}")
#
#         loss = mse(pred, Y_tr)
#         if not torch.isfinite(loss).item():
#             _handle_guard_fail("[TRAIN] Non-finite train loss")
#
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#         optimizer.step()
#
#         # --- VAL ---
#         model.eval()
#         with torch.no_grad():
#             with torch.cuda.amp.autocast(enabled=False):
#                 val_pred = model(Xb_val, Xt_val)
#             if val_pred.shape != Y_val.shape or not is_finite_tensor(val_pred):
#                 _handle_guard_fail(f"[VAL] pred bad: pred={tuple(val_pred.shape)} vs Y={tuple(Y_val.shape)}")
#             val_mse = mse(val_pred, Y_val).item()
#
#         # report per pruning (in debug non dovrebbe prunare, ma lo lasciamo)
#         if trial is not None:
#             trial.report(val_mse, step=epoch)
#             if trial.should_prune():
#                 raise optuna.TrialPruned()
#
#         # early stopping bookkeeping
#         if val_mse + min_delta < best_val:
#             best_val = val_mse
#             best_state = {k: v.detach().clone() for k, v in model.state_dict().items()}
#             no_improve = 0
#         else:
#             no_improve += 1
#             if no_improve >= patience:
#                 if DEBUG:
#                     print(f"[EARLY] stop at epoch {epoch} (best_val={best_val:.6g})")
#                 break
#
#         if DEBUG and (epoch % 5 == 0 or epoch == max_epochs-1):
#             print(f"[EPOCH {epoch:03d}] train_mse={loss.item():.6g}  val_mse={val_mse:.6g}")
#
#     if best_state is not None:
#         model.load_state_dict(best_state)
#     return best_val
#
# # ---------------------------
# # *** Assunzione ***:
# # Le seguenti variabili DEVONO esistere prima:
# #   device, Xb_train, Xt_train, Y_train, Xb_test, Xt_test, Y_test
# #   e la classe DeepONet1dSep deve essere definita.
# # Applichiamo fix shape e pulizia non-finiti subito.
# # ---------------------------
# # Uniforma shape
# Xb_train, Xt_train, Y_train = ensure_shapes(Xb_train, Xt_train, Y_train)
# Xb_test,  Xt_test,  Y_test  = ensure_shapes(Xb_test,  Xt_test,  Y_test)
#
# # Pulizia NaN/Inf
# clean_non_finite_("Xb_train", Xb_train)
# clean_non_finite_("Xt_train", Xt_train)
# clean_non_finite_("Y_train", Y_train)
# clean_non_finite_("Xb_test",  Xb_test)
# clean_non_finite_("Xt_test",  Xt_test)
# clean_non_finite_("Y_test",   Y_test)
#
# # ---------------------------
# # Objective (uguale ai tuoi iper, con dropouts)
# # ---------------------------
# def objective(trial: optuna.Trial):
#     dropout_branch = trial.suggest_float("dropout_branch", 0.0, 0.5)
#     dropout_trunk  = trial.suggest_float("dropout_trunk", 0.0, 0.5)
#
#     interact_size  = trial.suggest_int("interact_size", 5, 100, step=30)
#     branch_width   = trial.suggest_int("branch_width", 10, 200, step=30)
#     branch_depth   = trial.suggest_int("branch_depth", 1, 5)
#     branch_act     = trial.suggest_categorical("branch_activation", [nn.ReLU, nn.Tanh, nn.GELU])
#
#     trunk_width    = trial.suggest_int("trunk_width", 10, 200, step=30)
#     trunk_depth    = trial.suggest_int("trunk_depth", 1, 5)
#     trunk_act      = trial.suggest_categorical("trunk_activation", [nn.ReLU, nn.Tanh, nn.GELU])
#
#     lr             = trial.suggest_float("learning_rate", 1e-5, 1e-2, log=True)
#     l2             = trial.suggest_float("l2_reg_strength", 1e-5, 1e-2, log=True)
#
#     # build ctor per smoke test CPU
#     def build_model():
#         return DeepONet1dSep(
#             in_size_branch=Xb_train.shape[1],
#             interact_size=interact_size,
#             branch_width=branch_width,
#             branch_depth=branch_depth,
#             branch_activation=branch_act,
#             branch_dropout=dropout_branch,
#             trunk_input_dim=1,
#             trunk_width=trunk_width,
#             trunk_depth=trunk_depth,
#             trunk_activation=trunk_act,
#             trunk_dropout=dropout_trunk
#         )
#
#     def build_opt(params):
#         return optim.Adam(params, lr=lr, weight_decay=l2)
#
#     # --- CPU smoke test per beccare mismatch immediati ---
#     ok = cpu_smoke_test(build_model, build_opt, Xb_train, Xt_train, Y_train)
#     if not ok:  # in pratica alza già eccezione se c'è un problema
#         raise RuntimeError("[SMOKE] returned False unexpectedly")
#
#     # --- modello reale su device ---
#     model = build_model().to(device)
#     optimizer = build_opt(model.parameters())
#
#     # split train/val (deterministico)
#     Xb_tr, Xt_tr, Y_tr, Xb_val, Xt_val, Y_val = make_train_val_split(
#         Xb_train, Xt_train, Y_train, val_frac=0.15, seed=123
#     )
#
#     # train con early stopping + guardie
#     val_mse = train_with_early_stopping(
#         model, optimizer,
#         Xb_tr, Xt_tr, Y_tr,
#         Xb_val, Xt_val, Y_val,
#         max_epochs=200, patience=20, min_delta=0.0,
#         trial=trial
#     )
#     return val_mse
#
# # ---------------------------
# # Study + optimization (pruner disattivato in DEBUG)
# # ---------------------------
# # In debug usiamo NopPruner per vedere errori veri (non prune)
# pruner = optuna.pruners.NopPruner()
# study = optuna.create_study(direction="minimize", pruner=pruner)
#
# n_trials = 100  # in debug non serve 5000; alza dopo che passa
# with tqdm(total=n_trials, desc="Overall Optimization Progress", position=0, leave=True) as pbar:
#     def tqdm_callback(study, trial):
#         pbar.update(1)
#     study.optimize(objective, n_trials=n_trials, callbacks=[tqdm_callback], gc_after_trial=True)
#
# best_params = study.best_params
# print(f"[Optuna] Best parameters: {best_params}")
#
# # ---------------------------
# # Final training su train+val, eval su TEST
# # ---------------------------
# best_model = DeepONet1dSep(
#     in_size_branch=Xb_train.shape[1],
#     interact_size=best_params["interact_size"],
#     branch_width=best_params["branch_width"],
#     branch_depth=best_params["branch_depth"],
#     branch_activation=best_params["branch_activation"],
#     branch_dropout=best_params["dropout_branch"],
#     trunk_input_dim=1,
#     trunk_width=best_params["trunk_width"],
#     trunk_depth=best_params["trunk_depth"],
#     trunk_activation=best_params["trunk_activation"],
#     trunk_dropout=best_params["dropout_trunk"]
# ).to(device)
#
# best_opt = optim.Adam(
#     best_model.parameters(),
#     lr=best_params["learning_rate"],
#     weight_decay=best_params["l2_reg_strength"]
# )
#
# # Ri-usa il loop con val==train per comodità; si fermerà presto
# _ = train_with_early_stopping(
#     best_model, best_opt,
#     Xb_train, Xt_train, Y_train,   # train su tutti i dati disponibili
#     Xb_train, Xt_train, Y_train,   # 'val' == train per usare lo stesso loop
#     max_epochs=200, patience=20, min_delta=0.0,
#     trial=None
# )
#
# best_model.eval()
# with torch.no_grad():
#     Y_pred_test = best_model(Xb_test, Xt_test)
#     test_mse = torch.mean((Y_pred_test - Y_test)**2).item()
# print(f"[Final] Test MSE with best params: {test_mse:.6f}")
#
# # Salva best params
# with open("best_params.pkl", "wb") as f:
#     pickle.dump(best_params, f)
#
# # ===== ISTRUZIONI POST-DEBUG =====
# # - Quando tutto funziona, imposta DEBUG=False
# # - Ripristina un pruner vero:
# #     pruner = optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=20)
# # - In _handle_guard_fail torna a: raise optuna.TrialPruned()
# # - Alza n_trials a 500~2000 (o 5000 se vuoi) solo dopo che passa lo smoke test.

# %%
import os, pickle, math
import torch
import optuna
import torch.optim as optim
from torch import nn
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader

# --- Debug vs velocità ---
os.environ.setdefault("CUDA_LAUNCH_BLOCKING", "1")  # "0" se non ti servono stack CUDA
torch.backends.cudnn.benchmark = True               # True = più veloce se le shape sono fisse

# --- Device ---
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

# ==================== LOAD (CPU) ====================
Xb_train = torch.tensor(branch_inputs_train, dtype=torch.float32).contiguous()
Xt_train = torch.tensor(trunk_inputs_train,  dtype=torch.float32).contiguous()
Y_train  = torch.tensor(outputs_train,       dtype=torch.float32).contiguous()

Xb_val   = torch.tensor(branch_inputs_val,   dtype=torch.float32).contiguous()
Xt_val   = torch.tensor(trunk_inputs_val,    dtype=torch.float32).contiguous()
Y_val    = torch.tensor(outputs_val,         dtype=torch.float32).contiguous()

Xb_test  = torch.tensor(branch_inputs_test,  dtype=torch.float32).contiguous()
Xt_test  = torch.tensor(trunk_inputs_test,   dtype=torch.float32).contiguous()
Y_test   = torch.tensor(outputs_test,        dtype=torch.float32).contiguous()

# ==================== SHAPE FIX (Y -> (B,N,1), Xt -> (B,N,1)) ====================
def _assert_finite(name, t):
    if not torch.isfinite(t).all():
        raise ValueError(f"[DATA] Non-finite values in {name}.")

def _ensure_Y_3d(Y):
    # target: (B, N, 1)
    if Y.dim() == 2:
        Y = Y.unsqueeze(-1)  # (B,N) -> (B,N,1)
    assert Y.dim() == 3 and Y.size(-1) == 1, f"Y must be (B,N,1), got {tuple(Y.shape)}"
    return Y

def _make_Xt_3d(Xt, B_target, N_target):
    """
    Converte Xt in (B, N, 1) gestendo casi tipici:
      - (B,N,1) -> ok
      - (B,1) o (B,1,1) -> ripeti su N
      - (N,) o (N,1) -> tiling su B
      - (B*N,1) o (B*N,1,1) -> reshape a (B,N,1)
    """
    # già ok
    if Xt.dim() == 3 and Xt.size(0) == B_target and Xt.size(1) == N_target and Xt.size(2) == 1:
        return Xt
    # (B,1) -> (B,N,1)
    if Xt.dim() == 2 and Xt.size(0) == B_target and Xt.size(1) == 1:
        return Xt.unsqueeze(1).repeat(1, N_target, 1)
    # (B,1,1) -> (B,N,1)
    if Xt.dim() == 3 and Xt.size(0) == B_target and Xt.size(1) == 1 and Xt.size(2) == 1:
        return Xt.repeat(1, N_target, 1)
    # (N,) -> (B,N,1)
    if Xt.dim() == 1 and Xt.size(0) == N_target:
        return Xt.view(1, N_target, 1).repeat(B_target, 1, 1)
    # (N,1) -> (B,N,1)
    if Xt.dim() == 2 and Xt.size(0) == N_target and Xt.size(1) == 1:
        return Xt.unsqueeze(0).repeat(B_target, 1, 1)
    # (B*N,1) -> (B,N,1)
    if Xt.dim() == 2 and Xt.size(0) == B_target * N_target and Xt.size(1) == 1:
        return Xt.view(B_target, N_target, 1)
    # (B*N,1,1) -> (B,N,1)
    if Xt.dim() == 3 and Xt.size(0) == B_target * N_target and Xt.size(1) == 1 and Xt.size(2) == 1:
        return Xt.view(B_target, N_target, 1)
    raise AssertionError(f"Xt shape {tuple(Xt.shape)} non compatibile con (B={B_target}, N={N_target}, 1).")

# finite check
for name, t in [("Xb_train", Xb_train), ("Xt_train", Xt_train), ("Y_train", Y_train),
                ("Xb_val", Xb_val), ("Xt_val", Xt_val), ("Y_val", Y_val),
                ("Xb_test", Xb_test), ("Xt_test", Xt_test), ("Y_test", Y_test)]:
    _assert_finite(name, t)

# Y -> (B,N,1)
Y_train = _ensure_Y_3d(Y_train).contiguous()
Y_val   = _ensure_Y_3d(Y_val).contiguous()
Y_test  = _ensure_Y_3d(Y_test).contiguous()

# Coerenza B (se fallisce, gli split non sono stati fatti con gli stessi indici)
assert Xb_train.size(0) == Y_train.size(0), f"[TRAIN] B mismatch: Xb={Xb_train.size(0)} vs Y={Y_train.size(0)}"
assert Xb_val.size(0)   == Y_val.size(0),   f"[VAL]   B mismatch: Xb={Xb_val.size(0)} vs Y={Y_val.size(0)}"
assert Xb_test.size(0)  == Y_test.size(0),  f"[TEST]  B mismatch: Xb={Xb_test.size(0)} vs Y={Y_test.size(0)}"

# Xt -> (B,N,1)
N_tr, N_vl, N_ts = Y_train.size(1), Y_val.size(1), Y_test.size(1)
Xt_train = _make_Xt_3d(Xt_train, Xb_train.size(0), N_tr).contiguous()
Xt_val   = _make_Xt_3d(Xt_val,   Xb_val.size(0),   N_vl).contiguous()
Xt_test  = _make_Xt_3d(Xt_test,  Xb_test.size(0),  N_ts).contiguous()

print("[SHAPES] Train:", tuple(Xb_train.shape), tuple(Xt_train.shape), tuple(Y_train.shape))
print("[SHAPES] Val:  ", tuple(Xb_val.shape),   tuple(Xt_val.shape),   tuple(Y_val.shape))
print("[SHAPES] Test: ", tuple(Xb_test.shape),  tuple(Xt_test.shape),  tuple(Y_test.shape))

# ==================== DATALOADERS (CPU -> device nel loop) ====================
class TwoInputDataset(Dataset):
    def __init__(self, xb, xt, y):
        assert xb.size(0) == xt.size(0) == y.size(0), \
            f"B mismatch: Xb={xb.size(0)}, Xt={xt.size(0)}, Y={y.size(0)}"
        self.xb, self.xt, self.y = xb, xt, y
    def __len__(self): return self.y.size(0)
    def __getitem__(self, idx): return self.xb[idx], self.xt[idx], self.y[idx]

batch_size = 256           # riduci se serve VRAM
num_workers = 0            # Windows/Jupyter -> 0
pin_mem = (device.type == "cuda")

train_loader = DataLoader(TwoInputDataset(Xb_train, Xt_train, Y_train),
                          batch_size=batch_size, shuffle=True,
                          num_workers=num_workers, pin_memory=pin_mem)
val_loader   = DataLoader(TwoInputDataset(Xb_val, Xt_val, Y_val),
                          batch_size=batch_size, shuffle=False,
                          num_workers=num_workers, pin_memory=pin_mem)

# ==================== AMP (senza FutureWarning) ====================
USE_BF16  = (device.type == "cuda" and torch.cuda.is_bf16_supported())
AMP_DTYPE = torch.bfloat16 if USE_BF16 else torch.float16
use_amp   = (device.type == "cuda")
scaler    = torch.amp.GradScaler("cuda", enabled=(use_amp and not USE_BF16))
mse_loss  = nn.MSELoss()
grad_accum_steps = 1

def _run_train_val_once(model, optimizer, dev):
    model.train()
    running = 0.0
    optimizer.zero_grad(set_to_none=True)

    for step, (xb, xt, yy) in enumerate(train_loader, start=1):
        xb = xb.to(dev, non_blocking=True).contiguous()
        xt = xt.to(dev, non_blocking=True).contiguous()
        yy = yy.to(dev, non_blocking=True).contiguous()

        with torch.autocast(device_type=("cuda" if dev.type=="cuda" else "cpu"),
                            dtype=AMP_DTYPE, enabled=use_amp):
            pred = model(xb, xt)
            if pred.shape != yy.shape:
                raise RuntimeError(f"[SHAPE] pred {pred.shape} vs Y {yy.shape}")
            loss = mse_loss(pred, yy) / grad_accum_steps

        if scaler.is_enabled():
            scaler.scale(loss).backward()
        else:
            loss.backward()

        if step % grad_accum_steps == 0:
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            if scaler.is_enabled():
                scaler.step(optimizer); scaler.update()
            else:
                optimizer.step()
            optimizer.zero_grad(set_to_none=True)

        running += loss.item() * grad_accum_steps

    train_loss_epoch = running / max(1, len(train_loader))

    # ---- Val ----
    model.eval()
    val_running = 0.0
    with torch.no_grad():
        for xb, xt, yy in val_loader:
            xb = xb.to(dev, non_blocking=True).contiguous()
            xt = xt.to(dev, non_blocking=True).contiguous()
            yy = yy.to(dev, non_blocking=True).contiguous()
            with torch.autocast(device_type=("cuda" if dev.type=="cuda" else "cpu"),
                                dtype=AMP_DTYPE, enabled=use_amp):
                pv = model(xb, xt)
                if pv.shape != yy.shape:
                    raise RuntimeError(f"[SHAPE] val pred {pv.shape} vs Y {yy.shape}")
                vloss = mse_loss(pv, yy)
            val_running += float(vloss.item())

    val_loss_epoch = val_running / max(1, len(val_loader))
    return float(train_loss_epoch), float(val_loss_epoch)

# ==================== OPTUNA (epoche corte; niente torch.compile se Triton manca) ====================
_ACT_NAMES = ("relu", "tanh", "gelu")
def _act_from_name(name: str):
    return {"relu": nn.ReLU, "tanh": nn.Tanh, "gelu": nn.GELU}[name]

def objective(trial: optuna.Trial):
    interact_size  = trial.suggest_int("interact_size", 5, 95, step=30)
    branch_width   = trial.suggest_int("branch_width", 10, 190, step=30)
    branch_depth   = trial.suggest_int("branch_depth", 1, 5)
    trunk_width    = trial.suggest_int("trunk_width", 10, 190, step=30)
    trunk_depth    = trial.suggest_int("trunk_depth", 1, 5)
    branch_act_n   = trial.suggest_categorical("branch_activation", _ACT_NAMES)
    trunk_act_n    = trial.suggest_categorical("trunk_activation",  _ACT_NAMES)
    dropout_branch = trial.suggest_float("dropout_branch", 0.0, 0.5)
    dropout_trunk  = trial.suggest_float("dropout_trunk",  0.0, 0.5)
    lr             = trial.suggest_float("learning_rate", 1e-4, 3e-3, log=True)
    l2             = trial.suggest_float("l2_reg_strength", 1e-6, 1e-3, log=True)

    branch_act = _act_from_name(branch_act_n)
    trunk_act  = _act_from_name(trunk_act_n)

    model = DeepONet1dSep(
        in_size_branch=Xb_train.shape[1],
        interact_size=interact_size,
        branch_width=branch_width,
        branch_depth=branch_depth,
        branch_activation=branch_act,
        branch_dropout=dropout_branch,
        trunk_input_dim=1,
        trunk_width=trunk_width,
        trunk_depth=trunk_depth,
        trunk_activation=trunk_act,
        trunk_dropout=dropout_trunk
    ).to(device).float()

    # Usa torch.compile solo se Triton è disponibile (evita BackendCompilerFailed su Windows)
    USE_COMPILE = False
    if hasattr(torch, "compile") and device.type == "cuda":
        try:
            import triton  # noqa: F401
            USE_COMPILE = True
        except Exception:
            USE_COMPILE = False
    if USE_COMPILE:
        try:
            model = torch.compile(model)
        except Exception:
            pass  # fallback al modo eager

    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=l2)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.5, patience=2)

    num_epochs = 20
    patience   = 5
    best_val = float("inf")
    bad = 0

    for epoch in range(num_epochs):
        train_loss, val_loss = _run_train_val_once(model, optimizer, device)
        trial.report(val_loss, step=epoch)  # report needed for pruning

        # ---- pruning check (gentle) ----
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

        if val_loss < best_val - 1e-7:
            best_val = val_loss; bad = 0
        else:
            bad += 1
            if bad >= patience:
                break

        scheduler.step(val_loss)

    return best_val
    
######################################## Trial
"""
study = optuna.create_study(direction="minimize", pruner=optuna.pruners.NopPruner()) #with pruning
"""
# ===== Persistent Optuna study (resume with load=True) =====
from pathlib import Path
import optuna

# ---- choose pruner (gentle) ----
PRUNER = optuna.pruners.MedianPruner(
    n_startup_trials=15,   # let enough trials run unpruned
    n_warmup_steps=8,      # epochs before using intermediate values
    interval_steps=2       # check every 2 epochs
)

def get_study(*, load: bool, study_name: str = "deeponet_v1", db_path: str = "deeponet_v1.db", pruner=None):
    storage_url = f"sqlite:///{db_path}"
    if pruner is None:
        pruner = optuna.pruners.NopPruner()  # default fallback

    if load:
        try:
            study = optuna.load_study(study_name=study_name, storage=storage_url, pruner=pruner)
            print(f"[Optuna] Loaded existing study '{study_name}' from {db_path}")
        except KeyError:
            study = optuna.create_study(
                direction="minimize",
                study_name=study_name,
                storage=storage_url,
                load_if_exists=True,
                pruner=pruner,
            )
            print(f"[Optuna] Created new study '{study_name}' in {db_path}")
    else:
        p = Path(db_path)
        if p.exists():
            p.unlink()
            print(f"[Optuna] Removed previous DB at {db_path}")
        study = optuna.create_study(
            direction="minimize",
            study_name=study_name,
            storage=storage_url,
            load_if_exists=False,
            pruner=pruner,
        )
        print(f"[Optuna] Created NEW study '{study_name}' in {db_path}")
    return study

# choose here
LOAD_STUDY = True   # set False to start fresh
STUDY_NAME = "deeponet_v1"
DB_PATH    = "deeponet_v1.db"

study = get_study(load=LOAD_STUDY, study_name=STUDY_NAME, db_path=DB_PATH, pruner=PRUNER)
########################################



n_trials = 500
with tqdm(total=n_trials, desc="Overall Optimization Progress", position=0, leave=True) as pbar:
    def tqdm_callback(study, trial):
        pbar.update(1)
    study.optimize(objective, n_trials=n_trials, callbacks=[tqdm_callback], catch=(Exception,))

best_params = study.best_params
print(f"Best parameters: {best_params}")

with open("best_params.pkl", "wb") as f:
    pickle.dump(best_params, f)
# Out:
# [SHAPES] Train: (1050, 1000) (1050, 1000, 1) (1050, 1000, 1)
# [SHAPES] Val:   (150, 1000) (150, 1000, 1) (150, 1000, 1)
# [SHAPES] Test:  (300, 1000) (300, 1000, 1) (300, 1000, 1)
# [Optuna] Loaded existing study 'deeponet_v1' from deeponet_v1.db
# Overall Optimization Progress:   0%|                                                           | 0/500 [00:00<?, ?it/s][I 2025-09-11 11:29:06,131] Trial 191 finished with value: 0.0037562891375273466 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.07577679941481477, 'dropout_trunk': 0.05166069633414766, 'learning_rate': 0.0005582233336634958, 'l2_reg_strength': 2.1476412324497966e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   0%|                                                 | 1/500 [00:11<1:36:48, 11.64s/it][I 2025-09-11 11:29:16,612] Trial 192 finished with value: 0.005290237721055746 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.07710153554778484, 'dropout_trunk': 0.05486863722650239, 'learning_rate': 0.0005745712052688982, 'l2_reg_strength': 2.209366165864353e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   0%|▏                                                | 2/500 [00:22<1:30:54, 10.95s/it][I 2025-09-11 11:29:26,962] Trial 193 finished with value: 0.003983925562351942 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.058814538596908834, 'dropout_trunk': 0.029954711087498673, 'learning_rate': 0.0005343261882101821, 'l2_reg_strength': 1.990441271984913e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   1%|▎                                                | 3/500 [00:32<1:28:27, 10.68s/it][I 2025-09-11 11:29:37,175] Trial 194 finished with value: 0.004514578264206648 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.05986373526412036, 'dropout_trunk': 0.050317629148218856, 'learning_rate': 0.000532070842412702, 'l2_reg_strength': 1.982152618487023e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   1%|▍                                                | 4/500 [00:42<1:26:44, 10.49s/it][I 2025-09-11 11:29:47,646] Trial 195 finished with value: 0.004575871862471104 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.057934032189550545, 'dropout_trunk': 0.054460571041980765, 'learning_rate': 0.0005303760705600301, 'l2_reg_strength': 1.4836828036625878e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   1%|▍                                                | 5/500 [00:53<1:26:29, 10.48s/it][I 2025-09-11 11:29:58,155] Trial 196 finished with value: 0.004999151453375816 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.05750372264153433, 'dropout_trunk': 0.05206952632574732, 'learning_rate': 0.000544139442586351, 'l2_reg_strength': 1.2954461678826727e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   1%|▌                                                | 6/500 [01:03<1:26:24, 10.50s/it][I 2025-09-11 11:30:08,930] Trial 197 finished with value: 0.0043983254581689835 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.05947009537961775, 'dropout_trunk': 0.029177276009310058, 'learning_rate': 0.0005047934774167332, 'l2_reg_strength': 1.910415612920927e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   1%|▋                                                | 7/500 [01:14<1:26:58, 10.58s/it][I 2025-09-11 11:30:19,309] Trial 198 finished with value: 0.005088157020509243 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.0682787292457308, 'dropout_trunk': 0.0315208408177403, 'learning_rate': 0.0005061284087000388, 'l2_reg_strength': 1.9586486299447326e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   2%|▊                                                | 8/500 [01:24<1:26:15, 10.52s/it][I 2025-09-11 11:30:30,172] Trial 199 finished with value: 0.004030154552310705 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.07435855179285394, 'dropout_trunk': 0.05059214380596332, 'learning_rate': 0.0006000527437351222, 'l2_reg_strength': 1.6557008431429953e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   2%|▉                                                | 9/500 [01:35<1:26:58, 10.63s/it][I 2025-09-11 11:30:40,857] Trial 200 finished with value: 0.004520930349826813 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.077187658283725, 'dropout_trunk': 0.03392244705652018, 'learning_rate': 0.0006075327340029117, 'l2_reg_strength': 1.0479189462263076e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   2%|▉                                               | 10/500 [01:46<1:26:56, 10.65s/it][I 2025-09-11 11:30:48,492] Trial 201 pruned.
# Overall Optimization Progress:   2%|█                                               | 11/500 [01:53<1:19:15,  9.73s/it][I 2025-09-11 11:30:58,767] Trial 202 finished with value: 0.0046007065102458 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.08407297865520677, 'dropout_trunk': 0.02743284919187199, 'learning_rate': 0.0004994032267086985, 'l2_reg_strength': 2.0692247979215952e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   2%|█▏                                              | 12/500 [02:04<1:20:27,  9.89s/it][I 2025-09-11 11:31:09,568] Trial 203 finished with value: 0.0038106159772723913 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.056651284039372606, 'dropout_trunk': 0.041071040197776756, 'learning_rate': 0.0005773651517281976, 'l2_reg_strength': 2.5077436739774473e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   3%|█▏                                              | 13/500 [02:15<1:22:31, 10.17s/it][I 2025-09-11 11:31:15,879] Trial 204 pruned.
# Overall Optimization Progress:   3%|█▎                                              | 14/500 [02:21<1:12:55,  9.00s/it][I 2025-09-11 11:31:22,359] Trial 205 pruned.
# Overall Optimization Progress:   3%|█▍                                              | 15/500 [02:27<1:06:37,  8.24s/it][I 2025-09-11 11:31:28,272] Trial 206 pruned.
# Overall Optimization Progress:   3%|█▌                                              | 16/500 [02:33<1:00:50,  7.54s/it][I 2025-09-11 11:31:38,850] Trial 207 finished with value: 0.004404991865158081 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.07578764188816045, 'dropout_trunk': 0.04415523683078212, 'learning_rate': 0.0004987420798882978, 'l2_reg_strength': 1.8629336682155444e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   3%|█▋                                              | 17/500 [02:44<1:08:02,  8.45s/it][I 2025-09-11 11:31:49,817] Trial 208 finished with value: 0.0040763970464468 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.07009695475664302, 'dropout_trunk': 0.038094909421509685, 'learning_rate': 0.0004938547553829474, 'l2_reg_strength': 1.6625212019111335e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   4%|█▋                                              | 18/500 [02:55<1:13:57,  9.21s/it][I 2025-09-11 11:32:00,126] Trial 209 finished with value: 0.006133180111646652 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.07403902084737923, 'dropout_trunk': 0.06172418254399538, 'learning_rate': 0.0004985958307042893, 'l2_reg_strength': 1.5860891492775357e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   4%|█▊                                              | 19/500 [03:05<1:16:28,  9.54s/it][I 2025-09-11 11:32:11,094] Trial 210 finished with value: 0.003961697220802307 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.092153216330706, 'dropout_trunk': 0.040901158925036166, 'learning_rate': 0.0006728677850211226, 'l2_reg_strength': 1.7431870895177853e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   4%|█▉                                              | 20/500 [03:16<1:19:44,  9.97s/it][I 2025-09-11 11:32:17,361] Trial 211 pruned.
# Overall Optimization Progress:   4%|██                                              | 21/500 [03:22<1:10:43,  8.86s/it][I 2025-09-11 11:32:28,398] Trial 212 finished with value: 0.005264645908027887 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.08364105213215084, 'dropout_trunk': 0.04118486947969439, 'learning_rate': 0.0006588097012801581, 'l2_reg_strength': 1.2572477344805819e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   4%|██                                              | 22/500 [03:33<1:15:45,  9.51s/it][I 2025-09-11 11:32:39,148] Trial 213 finished with value: 0.0044628954492509365 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.07749223231837185, 'dropout_trunk': 0.05933736247532345, 'learning_rate': 0.0005996814683050022, 'l2_reg_strength': 1.8089880249357903e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   5%|██▏                                             | 23/500 [03:44<1:18:34,  9.88s/it][I 2025-09-11 11:32:49,978] Trial 214 finished with value: 0.005024261772632599 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.0892999660589123, 'dropout_trunk': 0.03493997641499921, 'learning_rate': 0.0004897887101962876, 'l2_reg_strength': 1.4516087181750418e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   5%|██▎                                             | 24/500 [03:55<1:20:39, 10.17s/it][I 2025-09-11 11:33:01,247] Trial 215 finished with value: 0.004876374267041683 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.06655572979527372, 'dropout_trunk': 0.01933290980197921, 'learning_rate': 0.0005628895924479447, 'l2_reg_strength': 2.169060921719912e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   5%|██▍                                             | 25/500 [04:06<1:23:06, 10.50s/it][I 2025-09-11 11:33:11,767] Trial 216 finished with value: 0.004155529197305441 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.05408072426159287, 'dropout_trunk': 0.025877138592038468, 'learning_rate': 0.0005171001708104641, 'l2_reg_strength': 2.799920823461223e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   5%|██▍                                             | 26/500 [04:17<1:22:59, 10.50s/it][I 2025-09-11 11:33:22,818] Trial 217 finished with value: 0.004324694629758596 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.06594183819951181, 'dropout_trunk': 0.02787674536162625, 'learning_rate': 0.0005111683895891282, 'l2_reg_strength': 2.5175531127678722e-06}. Best is trial 191 with value: 0.0037562891375273466.
# Overall Optimization Progress:   5%|██▌                                             | 27/500 [04:28<1:24:05, 10.67s/it][I 2025-09-11 11:33:33,662] Trial 218 finished with value: 0.0034978564362972975 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.055297282618531375, 'dropout_trunk': 0.024834995034626474, 'learning_rate': 0.0006249666155868136, 'l2_reg_strength': 2.413240001591498e-06}. Best is trial 218 with value: 0.0034978564362972975.
# Overall Optimization Progress:   6%|██▋                                             | 28/500 [04:39<1:24:20, 10.72s/it][I 2025-09-11 11:33:45,144] Trial 219 finished with value: 0.004041144624352455 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.05187577604709977, 'dropout_trunk': 0.02325660105026134, 'learning_rate': 0.0006241986273739559, 'l2_reg_strength': 2.634768879588162e-06}. Best is trial 218 with value: 0.0034978564362972975.
# Overall Optimization Progress:   6%|██▊                                             | 29/500 [04:50<1:25:57, 10.95s/it][I 2025-09-11 11:33:55,230] Trial 220 finished with value: 0.0035566084552556276 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.06924036825201695, 'dropout_trunk': 0.026242850570870283, 'learning_rate': 0.0007278810528222423, 'l2_reg_strength': 2.4308245638648214e-06}. Best is trial 218 with value: 0.0034978564362972975.
# Overall Optimization Progress:   6%|██▉                                             | 30/500 [05:00<1:23:44, 10.69s/it][I 2025-09-11 11:34:01,494] Trial 221 pruned.
# Overall Optimization Progress:   6%|██▉                                             | 31/500 [05:06<1:13:11,  9.36s/it][I 2025-09-11 11:34:12,184] Trial 222 finished with value: 0.003374516498297453 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.053686765408445775, 'dropout_trunk': 0.023451602840353237, 'learning_rate': 0.000710479358888835, 'l2_reg_strength': 2.841605284697154e-06}. Best is trial 222 with value: 0.003374516498297453.
# Overall Optimization Progress:   6%|███                                             | 32/500 [05:17<1:16:08,  9.76s/it][I 2025-09-11 11:34:18,264] Trial 223 pruned.
# Overall Optimization Progress:   7%|███▏                                            | 33/500 [05:23<1:07:21,  8.65s/it][I 2025-09-11 11:34:29,013] Trial 224 finished with value: 0.0038287320639938116 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.05186263608443642, 'dropout_trunk': 0.04688080229005331, 'learning_rate': 0.0007447313473431241, 'l2_reg_strength': 2.331531410385598e-06}. Best is trial 222 with value: 0.003374516498297453.
# Overall Optimization Progress:   7%|███▎                                            | 34/500 [05:34<1:12:05,  9.28s/it][I 2025-09-11 11:34:39,974] Trial 225 finished with value: 0.0036094242241233587 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.052657204215970865, 'dropout_trunk': 0.046562264890435925, 'learning_rate': 0.0007359021967581961, 'l2_reg_strength': 2.2746897380649914e-06}. Best is trial 222 with value: 0.003374516498297453.
# Overall Optimization Progress:   7%|███▎                                            | 35/500 [05:45<1:15:51,  9.79s/it][I 2025-09-11 11:34:50,194] Trial 226 finished with value: 0.004153032787144184 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.0514292906455656, 'dropout_trunk': 0.04869279005392296, 'learning_rate': 0.0007777748484177788, 'l2_reg_strength': 2.1909102767713303e-06}. Best is trial 222 with value: 0.003374516498297453.
# Overall Optimization Progress:   7%|███▍                                            | 36/500 [05:55<1:16:42,  9.92s/it][I 2025-09-11 11:35:00,940] Trial 227 finished with value: 0.0033335203770548105 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.06270823897277218, 'dropout_trunk': 0.06220893729024465, 'learning_rate': 0.0007589051731255925, 'l2_reg_strength': 2.20297785398036e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   7%|███▌                                            | 37/500 [06:06<1:18:27, 10.17s/it][I 2025-09-11 11:35:11,691] Trial 228 finished with value: 0.00440607825294137 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.053178567896668555, 'dropout_trunk': 0.06402422469841457, 'learning_rate': 0.000785279645150366, 'l2_reg_strength': 2.06324735946495e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   8%|███▋                                            | 38/500 [06:17<1:19:36, 10.34s/it][I 2025-09-11 11:35:22,264] Trial 229 finished with value: 0.005498087499290705 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.05408872001773711, 'dropout_trunk': 0.05030002952675786, 'learning_rate': 0.0007468932486969197, 'l2_reg_strength': 2.2757526102671624e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   8%|███▋                                            | 39/500 [06:27<1:20:00, 10.41s/it][I 2025-09-11 11:35:32,668] Trial 230 finished with value: 0.0045330459251999855 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.06618606702075314, 'dropout_trunk': 0.04411360047527484, 'learning_rate': 0.0007156972357662541, 'l2_reg_strength': 2.2748813056828863e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   8%|███▊                                            | 40/500 [06:38<1:19:47, 10.41s/it][I 2025-09-11 11:35:43,886] Trial 231 finished with value: 0.0037581913638859987 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.05239182319860028, 'dropout_trunk': 0.055339221053003214, 'learning_rate': 0.0006816691436034938, 'l2_reg_strength': 2.8872460591698373e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   8%|███▉                                            | 41/500 [06:49<1:21:28, 10.65s/it][I 2025-09-11 11:35:54,703] Trial 232 finished with value: 0.00531038548797369 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.06131955127169307, 'dropout_trunk': 0.06868234469260115, 'learning_rate': 0.0006709050658533529, 'l2_reg_strength': 2.9652584913481035e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   8%|████                                            | 42/500 [07:00<1:21:40, 10.70s/it][I 2025-09-11 11:36:05,311] Trial 233 finished with value: 0.0038514803163707256 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.08475502197381289, 'dropout_trunk': 0.060212791546610106, 'learning_rate': 0.0007450001808289366, 'l2_reg_strength': 2.4428671653848106e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   9%|████▏                                           | 43/500 [07:10<1:21:18, 10.67s/it][I 2025-09-11 11:36:15,286] Trial 234 finished with value: 0.00423004012554884 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.09085433760185188, 'dropout_trunk': 0.05872510909343626, 'learning_rate': 0.0007200627020529759, 'l2_reg_strength': 1.6957926788477189e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   9%|████▏                                           | 44/500 [07:20<1:19:31, 10.46s/it][I 2025-09-11 11:36:26,872] Trial 235 finished with value: 0.004647805355489254 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.0741712585034034, 'dropout_trunk': 0.05298066513440243, 'learning_rate': 0.0007886042397550729, 'l2_reg_strength': 2.3482023142009657e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   9%|████▎                                           | 45/500 [07:32<1:21:53, 10.80s/it][I 2025-09-11 11:36:36,197] Trial 236 finished with value: 0.00439996924251318 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.08489514196759221, 'dropout_trunk': 0.0711642031761622, 'learning_rate': 0.0007461746242399277, 'l2_reg_strength': 2.0832152383562394e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   9%|████▍                                           | 46/500 [07:41<1:18:22, 10.36s/it][I 2025-09-11 11:36:47,174] Trial 237 finished with value: 0.003871376859024167 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.04949077607370821, 'dropout_trunk': 0.04532505935909064, 'learning_rate': 0.0008442622543473193, 'l2_reg_strength': 2.686022943045663e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:   9%|████▌                                           | 47/500 [07:52<1:19:36, 10.54s/it][I 2025-09-11 11:36:58,208] Trial 238 finished with value: 0.0038995174691081047 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.03541811440147145, 'dropout_trunk': 0.0395187801751106, 'learning_rate': 0.0008347979954401416, 'l2_reg_strength': 2.6025479498685385e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  10%|████▌                                           | 48/500 [08:03<1:20:32, 10.69s/it][I 2025-09-11 11:37:04,930] Trial 239 pruned.
# Overall Optimization Progress:  10%|████▋                                           | 49/500 [08:10<1:11:25,  9.50s/it][I 2025-09-11 11:37:16,395] Trial 240 finished with value: 0.003379149828106165 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.031646851849435734, 'dropout_trunk': 0.04426207742980143, 'learning_rate': 0.00065974255624808, 'l2_reg_strength': 2.9857720108699386e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  10%|████▊                                           | 50/500 [08:21<1:15:39, 10.09s/it][I 2025-09-11 11:37:26,785] Trial 241 finished with value: 0.005398254841566086 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.0342582528260062, 'dropout_trunk': 0.06566822379659916, 'learning_rate': 0.0006874678103932624, 'l2_reg_strength': 3.11406315062823e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  10%|████▉                                           | 51/500 [08:32<1:16:10, 10.18s/it][I 2025-09-11 11:37:33,312] Trial 242 pruned.
# Overall Optimization Progress:  10%|████▉                                           | 52/500 [08:38<1:07:50,  9.09s/it][I 2025-09-11 11:37:46,019] Trial 243 finished with value: 0.004028880503028631 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.04499718542697688, 'dropout_trunk': 0.04536622442325733, 'learning_rate': 0.0008521910002837626, 'l2_reg_strength': 2.48327115405577e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  11%|█████                                           | 53/500 [08:51<1:15:45, 10.17s/it][I 2025-09-11 11:37:56,475] Trial 244 finished with value: 0.004192988388240337 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.04694532057980356, 'dropout_trunk': 0.038191580911304576, 'learning_rate': 0.0008595429425303303, 'l2_reg_strength': 2.915100107945867e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  11%|█████▏                                          | 54/500 [09:01<1:16:15, 10.26s/it][I 2025-09-11 11:38:07,128] Trial 245 finished with value: 0.004731690511107445 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.06182496651846763, 'dropout_trunk': 0.05872812476977727, 'learning_rate': 0.0007429373618245886, 'l2_reg_strength': 2.404923661530695e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  11%|█████▎                                          | 55/500 [09:12<1:16:57, 10.38s/it][I 2025-09-11 11:38:16,867] Trial 246 finished with value: 0.004261619411408901 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.03383196790349541, 'dropout_trunk': 0.04735201738738059, 'learning_rate': 0.0008410263028892223, 'l2_reg_strength': 2.5228947647328576e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  11%|█████▍                                          | 56/500 [09:22<1:15:20, 10.18s/it][I 2025-09-11 11:38:27,387] Trial 247 finished with value: 0.004513144958764315 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.048405375135551106, 'dropout_trunk': 0.04756174525178582, 'learning_rate': 0.0006031647387784969, 'l2_reg_strength': 2.138135601178197e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  11%|█████▍                                          | 57/500 [09:32<1:15:56, 10.29s/it][I 2025-09-11 11:38:39,149] Trial 248 finished with value: 0.003398326924070716 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.03931828278467523, 'dropout_trunk': 0.03699582695897572, 'learning_rate': 0.0007702046665954175, 'l2_reg_strength': 2.990987235000334e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  12%|█████▌                                          | 58/500 [09:44<1:19:01, 10.73s/it][I 2025-09-11 11:38:48,798] Trial 249 finished with value: 0.003502974519506097 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.03946580158669548, 'dropout_trunk': 0.037610803423207294, 'learning_rate': 0.0008013826030321866, 'l2_reg_strength': 3.117339550704513e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  12%|█████▋                                          | 59/500 [09:54<1:16:28, 10.40s/it][I 2025-09-11 11:38:59,562] Trial 250 finished with value: 0.003866584040224552 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.02971903243646336, 'dropout_trunk': 0.03594017218346081, 'learning_rate': 0.0006987341023213129, 'l2_reg_strength': 3.1462836431389823e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  12%|█████▊                                          | 60/500 [10:05<1:17:05, 10.51s/it][I 2025-09-11 11:39:10,242] Trial 251 finished with value: 0.004392888862639666 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.02953278503541012, 'dropout_trunk': 0.038008410874378507, 'learning_rate': 0.0007021035301589378, 'l2_reg_strength': 3.0156292106065356e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  12%|█████▊                                          | 61/500 [10:15<1:17:17, 10.56s/it][I 2025-09-11 11:39:20,560] Trial 252 finished with value: 0.004841943737119436 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.03842718194984413, 'dropout_trunk': 0.03639812732390644, 'learning_rate': 0.0007773022135763345, 'l2_reg_strength': 3.4252833676855685e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  12%|█████▉                                          | 62/500 [10:26<1:16:33, 10.49s/it][I 2025-09-11 11:39:26,830] Trial 253 pruned.
# Overall Optimization Progress:  13%|██████                                          | 63/500 [10:32<1:07:10,  9.22s/it][I 2025-09-11 11:39:37,197] Trial 254 finished with value: 0.003726577153429389 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.05873068715503853, 'dropout_trunk': 0.03637047899522698, 'learning_rate': 0.0006584288996332974, 'l2_reg_strength': 3.1542956376653734e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  13%|██████▏                                         | 64/500 [10:42<1:09:30,  9.57s/it][I 2025-09-11 11:39:47,636] Trial 255 finished with value: 0.005517040845006704 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.05183438507928227, 'dropout_trunk': 0.0661648455376117, 'learning_rate': 0.0006819504298129329, 'l2_reg_strength': 2.9340964665336952e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  13%|██████▏                                         | 65/500 [10:53<1:11:14,  9.83s/it][I 2025-09-11 11:39:58,408] Trial 256 finished with value: 0.003662196919322014 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.03789978687429437, 'dropout_trunk': 0.037724444279659194, 'learning_rate': 0.0007381701596479235, 'l2_reg_strength': 3.3621361702302423e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  13%|██████▎                                         | 66/500 [11:03<1:13:07, 10.11s/it][I 2025-09-11 11:40:08,715] Trial 257 finished with value: 0.0039658453315496445 and parameters: {'interact_size': 5, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.02898746837727417, 'dropout_trunk': 0.03575861221627874, 'learning_rate': 0.000795039469675402, 'l2_reg_strength': 3.4006418964245397e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  13%|██████▍                                         | 67/500 [11:14<1:13:23, 10.17s/it][I 2025-09-11 11:40:14,954] Trial 258 pruned.
# Overall Optimization Progress:  14%|██████▌                                         | 68/500 [11:20<1:04:44,  8.99s/it][I 2025-09-11 11:40:25,714] Trial 259 finished with value: 0.003466017311438918 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'gelu', 'trunk_activation': 'relu', 'dropout_branch': 0.04690950380673102, 'dropout_trunk': 0.03585252663484896, 'learning_rate': 0.0007508523706359409, 'l2_reg_strength': 3.3551545836239213e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  14%|██████▌                                         | 69/500 [11:31<1:08:23,  9.52s/it][I 2025-09-11 11:40:35,881] Trial 260 finished with value: 0.003781137755140662 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.03919171060495784, 'dropout_trunk': 0.047381754322402714, 'learning_rate': 0.000809453477297886, 'l2_reg_strength': 2.6773637626569914e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  14%|██████▋                                         | 70/500 [11:41<1:09:37,  9.72s/it][I 2025-09-11 11:40:46,261] Trial 261 finished with value: 0.004426485393196344 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.031166476398964114, 'dropout_trunk': 0.07391253997537581, 'learning_rate': 0.0008210200654771406, 'l2_reg_strength': 2.618059153561148e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  14%|██████▊                                         | 71/500 [11:51<1:10:52,  9.91s/it][I 2025-09-11 11:40:56,290] Trial 262 finished with value: 0.004333246033638716 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.04903066531306723, 'dropout_trunk': 0.04787469233369598, 'learning_rate': 0.0007539842214744327, 'l2_reg_strength': 2.732632509780929e-06}. Best is trial 227 with value: 0.0033335203770548105.
# Overall Optimization Progress:  14%|██████▉                                         | 72/500 [12:01<1:10:58,  9.95s/it][I 2025-09-11 11:41:03,304] Trial 263 pruned.
# Overall Optimization Progress:  15%|███████                                         | 73/500 [12:08<1:04:32,  9.07s/it][I 2025-09-11 11:41:14,873] Trial 264 finished with value: 0.0030990552622824907 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.025828432632682145, 'dropout_trunk': 0.03924827296972866, 'learning_rate': 0.0007899607344668786, 'l2_reg_strength': 3.2463132150394327e-06}. Best is trial 264 with value: 0.0030990552622824907.
# Overall Optimization Progress:  15%|███████                                         | 74/500 [12:20<1:09:41,  9.82s/it][I 2025-09-11 11:41:25,798] Trial 265 finished with value: 0.0035583218559622765 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.022756474215034288, 'dropout_trunk': 0.0599248566476343, 'learning_rate': 0.000874664066699892, 'l2_reg_strength': 3.032929583044524e-06}. Best is trial 264 with value: 0.0030990552622824907.
# Overall Optimization Progress:  15%|███████▏                                        | 75/500 [12:31<1:11:54, 10.15s/it][I 2025-09-11 11:41:36,554] Trial 266 finished with value: 0.004079937934875488 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.022685319709745886, 'dropout_trunk': 0.06606585034611132, 'learning_rate': 0.0008772240394545393, 'l2_reg_strength': 3.1068611614495974e-06}. Best is trial 264 with value: 0.0030990552622824907.
# Overall Optimization Progress:  15%|███████▎                                        | 76/500 [12:42<1:13:01, 10.33s/it][I 2025-09-11 11:41:48,468] Trial 267 finished with value: 0.0033531261142343283 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.029360763772891426, 'dropout_trunk': 0.03778857593839974, 'learning_rate': 0.0008078098748030914, 'l2_reg_strength': 2.6232156668256327e-06}. Best is trial 264 with value: 0.0030990552622824907.
# Overall Optimization Progress:  15%|███████▍                                        | 77/500 [12:53<1:16:10, 10.81s/it][I 2025-09-11 11:42:00,222] Trial 268 finished with value: 0.004316790495067835 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.024930220120833308, 'dropout_trunk': 0.0567764359314671, 'learning_rate': 0.0007855238620168881, 'l2_reg_strength': 6.474915306185269e-05}. Best is trial 264 with value: 0.0030990552622824907.
# Overall Optimization Progress:  16%|███████▍                                        | 78/500 [13:05<1:18:00, 11.09s/it][I 2025-09-11 11:42:10,683] Trial 269 finished with value: 0.003150014206767082 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.014681547114234104, 'dropout_trunk': 0.05534700183078512, 'learning_rate': 0.0009698118213742889, 'l2_reg_strength': 2.9268996904280886e-06}. Best is trial 264 with value: 0.0030990552622824907.
# Overall Optimization Progress:  16%|███████▌                                        | 79/500 [13:16<1:16:29, 10.90s/it][I 2025-09-11 11:42:21,013] Trial 270 finished with value: 0.003083357121795416 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.011299673302873606, 'dropout_trunk': 0.05894123251121863, 'learning_rate': 0.0009893984377072156, 'l2_reg_strength': 3.1418690590976756e-06}. Best is trial 270 with value: 0.003083357121795416.
# Overall Optimization Progress:  16%|███████▋                                        | 80/500 [13:26<1:15:06, 10.73s/it][I 2025-09-11 11:42:31,648] Trial 271 finished with value: 0.0037557852920144796 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.011391034526206167, 'dropout_trunk': 0.06972308992908052, 'learning_rate': 0.0008925095183258122, 'l2_reg_strength': 3.341145656490028e-06}. Best is trial 270 with value: 0.003083357121795416.
# Overall Optimization Progress:  16%|███████▊                                        | 81/500 [13:37<1:14:45, 10.70s/it][I 2025-09-11 11:42:37,930] Trial 272 pruned.
# Overall Optimization Progress:  16%|███████▊                                        | 82/500 [13:43<1:05:20,  9.38s/it][I 2025-09-11 11:42:49,669] Trial 273 finished with value: 0.004515168722718954 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.012547429836609815, 'dropout_trunk': 0.06107490275331941, 'learning_rate': 0.0009818026065329536, 'l2_reg_strength': 2.2471979073876654e-06}. Best is trial 270 with value: 0.003083357121795416.
# Overall Optimization Progress:  17%|███████▉                                        | 83/500 [13:55<1:10:05, 10.09s/it][I 2025-09-11 11:42:59,934] Trial 274 finished with value: 0.003734035650268197 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.01003796321213003, 'dropout_trunk': 0.07205020785775132, 'learning_rate': 0.0009549906368772653, 'l2_reg_strength': 3.446131568683527e-06}. Best is trial 270 with value: 0.003083357121795416.
# Overall Optimization Progress:  17%|████████                                        | 84/500 [14:05<1:10:17, 10.14s/it][I 2025-09-11 11:43:09,637] Trial 275 finished with value: 0.004071091301739216 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.01263152727959669, 'dropout_trunk': 0.07255867012377414, 'learning_rate': 0.0009588586266312772, 'l2_reg_strength': 3.4788933324643445e-06}. Best is trial 270 with value: 0.003083357121795416.
# Overall Optimization Progress:  17%|████████▏                                       | 85/500 [14:15<1:09:12, 10.01s/it][I 2025-09-11 11:43:19,853] Trial 276 finished with value: 0.003776684869080782 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.008389497972283706, 'dropout_trunk': 0.07669820601797045, 'learning_rate': 0.0008644088076173249, 'l2_reg_strength': 2.9628226129425098e-06}. Best is trial 270 with value: 0.003083357121795416.
# Overall Optimization Progress:  17%|████████▎                                       | 86/500 [14:25<1:09:30, 10.07s/it][I 2025-09-11 11:43:30,536] Trial 277 finished with value: 0.0037628409918397665 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.0020527752365492, 'dropout_trunk': 0.07403832675949934, 'learning_rate': 0.0010414447603200015, 'l2_reg_strength': 3.0048782259335264e-06}. Best is trial 270 with value: 0.003083357121795416.
# Overall Optimization Progress:  17%|████████▎                                       | 87/500 [14:36<1:10:33, 10.25s/it][I 2025-09-11 11:43:40,944] Trial 278 finished with value: 0.004615413956344128 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.008422501028363238, 'dropout_trunk': 0.06985959356456894, 'learning_rate': 0.0010254750397932677, 'l2_reg_strength': 3.435193966044861e-06}. Best is trial 270 with value: 0.003083357121795416.
# Overall Optimization Progress:  18%|████████▍                                       | 88/500 [14:46<1:10:43, 10.30s/it][I 2025-09-11 11:43:51,243] Trial 279 finished with value: 0.0033817989751696587 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.001967171735043549, 'dropout_trunk': 0.08021932754417097, 'learning_rate': 0.00104210781630069, 'l2_reg_strength': 2.9345139655942844e-06}. Best is trial 270 with value: 0.003083357121795416.
# Overall Optimization Progress:  18%|████████▌                                       | 89/500 [14:56<1:10:33, 10.30s/it][I 2025-09-11 11:44:02,145] Trial 280 finished with value: 0.004689759574830532 and parameters: {'interact_size': 35, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.00017392367404949448, 'dropout_trunk': 0.09002872388402892, 'learning_rate': 0.0010631709981991178, 'l2_reg_strength': 3.0131870875858424e-06}. Best is trial 270 with value: 0.003083357121795416.
# ...
# Overall Optimization Progress:  92%|███████████████████████████████████████████▏   | 460/500 [1:14:11<06:04,  9.12s/it][I 2025-09-11 12:43:12,705] Trial 651 pruned.
# Overall Optimization Progress:  92%|███████████████████████████████████████████▎   | 461/500 [1:14:18<05:26,  8.38s/it][I 2025-09-11 12:43:18,719] Trial 652 pruned.
# Overall Optimization Progress:  92%|███████████████████████████████████████████▍   | 462/500 [1:14:24<04:51,  7.67s/it][I 2025-09-11 12:43:26,876] Trial 653 pruned.
# Overall Optimization Progress:  93%|███████████████████████████████████████████▌   | 463/500 [1:14:32<04:49,  7.82s/it][I 2025-09-11 12:43:40,707] Trial 654 finished with value: 0.0030495694372802973 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.00805191666141477, 'dropout_trunk': 0.017790476413802568, 'learning_rate': 0.0014807402087133408, 'l2_reg_strength': 2.414451711394472e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  93%|███████████████████████████████████████████▌   | 464/500 [1:14:46<05:46,  9.62s/it][I 2025-09-11 12:43:47,492] Trial 655 pruned.
# Overall Optimization Progress:  93%|███████████████████████████████████████████▋   | 465/500 [1:14:53<05:06,  8.77s/it][I 2025-09-11 12:43:58,759] Trial 656 finished with value: 0.002823087852448225 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 3.892530644760724e-05, 'dropout_trunk': 0.028093735487425678, 'learning_rate': 0.0013360483665485546, 'l2_reg_strength': 3.5585712869961655e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  93%|███████████████████████████████████████████▊   | 466/500 [1:15:04<05:23,  9.52s/it][I 2025-09-11 12:44:10,311] Trial 657 finished with value: 0.002759314374998212 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.027297801972896014, 'dropout_trunk': 0.014973663477606427, 'learning_rate': 0.0017503393864325286, 'l2_reg_strength': 4.123750996538586e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  93%|███████████████████████████████████████████▉   | 467/500 [1:15:15<05:34, 10.13s/it][I 2025-09-11 12:44:16,647] Trial 658 pruned.
# Overall Optimization Progress:  94%|███████████████████████████████████████████▉   | 468/500 [1:15:22<04:47,  8.99s/it][I 2025-09-11 12:44:27,146] Trial 659 finished with value: 0.003185311332345009 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.01653642899282141, 'dropout_trunk': 0.03533863735438436, 'learning_rate': 0.0019938357562112705, 'l2_reg_strength': 1.1548275980396297e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  94%|████████████████████████████████████████████   | 469/500 [1:15:32<04:52,  9.44s/it][I 2025-09-11 12:44:37,685] Trial 660 finished with value: 0.0033343294635415077 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.02427585079504522, 'dropout_trunk': 0.018333282505090854, 'learning_rate': 0.0014201047628867136, 'l2_reg_strength': 1.5469334780921762e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  94%|████████████████████████████████████████████▏  | 470/500 [1:15:43<04:53,  9.77s/it][I 2025-09-11 12:44:46,776] Trial 661 pruned.
# Overall Optimization Progress:  94%|████████████████████████████████████████████▎  | 471/500 [1:15:52<04:37,  9.57s/it][I 2025-09-11 12:44:55,136] Trial 662 pruned.
# Overall Optimization Progress:  94%|████████████████████████████████████████████▎  | 472/500 [1:16:00<04:17,  9.21s/it][I 2025-09-11 12:45:07,218] Trial 663 finished with value: 0.0032914099283516407 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.044918191178898594, 'dropout_trunk': 0.022836918295109147, 'learning_rate': 0.00150449649326337, 'l2_reg_strength': 2.810055931074415e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  95%|████████████████████████████████████████████▍  | 473/500 [1:16:12<04:31, 10.07s/it][I 2025-09-11 12:45:14,841] Trial 664 pruned.
# Overall Optimization Progress:  95%|████████████████████████████████████████████▌  | 474/500 [1:16:20<04:02,  9.34s/it][I 2025-09-11 12:45:28,278] Trial 665 finished with value: 0.0028686081059277058 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.03313762719657559, 'dropout_trunk': 0.015436947582376764, 'learning_rate': 0.001403419899228274, 'l2_reg_strength': 3.08515223692265e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  95%|████████████████████████████████████████████▋  | 475/500 [1:16:33<04:24, 10.56s/it][I 2025-09-11 12:45:36,210] Trial 666 pruned.
# Overall Optimization Progress:  95%|████████████████████████████████████████████▋  | 476/500 [1:16:41<03:54,  9.77s/it][I 2025-09-11 12:45:47,935] Trial 667 finished with value: 0.002826354932039976 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.00014072569389932468, 'dropout_trunk': 0.02668196152185736, 'learning_rate': 0.001713095512739532, 'l2_reg_strength': 2.5080013654822397e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  95%|████████████████████████████████████████████▊  | 477/500 [1:16:53<03:58, 10.36s/it][I 2025-09-11 12:46:01,909] Trial 668 finished with value: 0.0034155130852013826 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.014581800228511958, 'dropout_trunk': 0.01659151632518232, 'learning_rate': 0.0021375440439780416, 'l2_reg_strength': 3.836099457407553e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  96%|████████████████████████████████████████████▉  | 478/500 [1:17:07<04:11, 11.44s/it][I 2025-09-11 12:46:13,735] Trial 669 finished with value: 0.0033058198168873787 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.026280218779178886, 'dropout_trunk': 0.035713543097399776, 'learning_rate': 0.0012767592464703347, 'l2_reg_strength': 3.391274140138416e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  96%|█████████████████████████████████████████████  | 479/500 [1:17:19<04:02, 11.56s/it][I 2025-09-11 12:46:25,832] Trial 670 finished with value: 0.003318300237879157 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.009041697492640164, 'dropout_trunk': 0.05727024540348456, 'learning_rate': 0.001546289210604772, 'l2_reg_strength': 4.4963499096452687e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  96%|█████████████████████████████████████████████  | 480/500 [1:17:31<03:54, 11.72s/it][I 2025-09-11 12:46:40,999] Trial 671 finished with value: 0.003465589601546526 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 2, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.018493692418450416, 'dropout_trunk': 0.016465890502397017, 'learning_rate': 0.0018835647153881607, 'l2_reg_strength': 1.7465571978291634e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  96%|█████████████████████████████████████████████▏ | 481/500 [1:17:46<04:02, 12.75s/it][I 2025-09-11 12:46:48,354] Trial 672 pruned.
# Overall Optimization Progress:  96%|█████████████████████████████████████████████▎ | 482/500 [1:17:53<03:20, 11.14s/it][I 2025-09-11 12:47:00,199] Trial 673 finished with value: 0.0027222014032304287 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.01033768774340111, 'dropout_trunk': 0.04671313456088049, 'learning_rate': 0.0016425343437852465, 'l2_reg_strength': 2.3166755544065634e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  97%|█████████████████████████████████████████████▍ | 483/500 [1:18:05<03:12, 11.35s/it][I 2025-09-11 12:47:06,643] Trial 674 pruned.
# Overall Optimization Progress:  97%|█████████████████████████████████████████████▍ | 484/500 [1:18:12<02:38,  9.88s/it][I 2025-09-11 12:47:20,453] Trial 675 finished with value: 0.0031146847177296877 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.03295908045917204, 'dropout_trunk': 0.026290172327149235, 'learning_rate': 0.001797481656959291, 'l2_reg_strength': 3.4395898219530443e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  97%|█████████████████████████████████████████████▌ | 485/500 [1:18:25<02:45, 11.06s/it][I 2025-09-11 12:47:33,635] Trial 676 finished with value: 0.0028046739753335714 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.01828566337479645, 'dropout_trunk': 0.038090889685993036, 'learning_rate': 0.0011818988205345006, 'l2_reg_strength': 4.3226065941286024e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  97%|█████████████████████████████████████████████▋ | 486/500 [1:18:39<02:43, 11.69s/it][I 2025-09-11 12:47:44,560] Trial 677 finished with value: 0.003525935811921954 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.009679542226322653, 'dropout_trunk': 0.009537538488976023, 'learning_rate': 0.0013380338410381998, 'l2_reg_strength': 2.0174812442789504e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  97%|█████████████████████████████████████████████▊ | 487/500 [1:18:50<02:29, 11.46s/it][I 2025-09-11 12:47:50,959] Trial 678 pruned.
# Overall Optimization Progress:  98%|█████████████████████████████████████████████▊ | 488/500 [1:18:56<01:59,  9.95s/it][I 2025-09-11 12:47:57,401] Trial 679 pruned.
# Overall Optimization Progress:  98%|█████████████████████████████████████████████▉ | 489/500 [1:19:02<01:37,  8.89s/it][I 2025-09-11 12:48:07,774] Trial 680 finished with value: 0.003220296697691083 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.009099104980564689, 'dropout_trunk': 0.04968559708401664, 'learning_rate': 0.002075633755213218, 'l2_reg_strength': 2.9889973525371907e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  98%|██████████████████████████████████████████████ | 490/500 [1:19:13<01:33,  9.34s/it][I 2025-09-11 12:48:13,952] Trial 681 pruned.
# Overall Optimization Progress:  98%|██████████████████████████████████████████████▏| 491/500 [1:19:19<01:15,  8.39s/it][I 2025-09-11 12:48:20,523] Trial 682 pruned.
# Overall Optimization Progress:  98%|██████████████████████████████████████████████▏| 492/500 [1:19:26<01:02,  7.84s/it][I 2025-09-11 12:48:31,276] Trial 683 finished with value: 0.0030693088192492723 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.000276002413084641, 'dropout_trunk': 0.02951752226666271, 'learning_rate': 0.0016166195874810498, 'l2_reg_strength': 2.6636410457334554e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  99%|██████████████████████████████████████████████▎| 493/500 [1:19:36<01:01,  8.72s/it][I 2025-09-11 12:48:37,944] Trial 684 pruned.
# Overall Optimization Progress:  99%|██████████████████████████████████████████████▍| 494/500 [1:19:43<00:48,  8.10s/it][I 2025-09-11 12:48:50,184] Trial 685 finished with value: 0.0035609721671789885 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.018451594430577062, 'dropout_trunk': 0.02277444660266613, 'learning_rate': 0.001383580114753707, 'l2_reg_strength': 4.327402216827751e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress:  99%|██████████████████████████████████████████████▌| 495/500 [1:19:55<00:46,  9.34s/it][I 2025-09-11 12:48:57,220] Trial 686 pruned.
# Overall Optimization Progress:  99%|██████████████████████████████████████████████▌| 496/500 [1:20:02<00:34,  8.65s/it][I 2025-09-11 12:49:03,652] Trial 687 pruned.
# Overall Optimization Progress:  99%|██████████████████████████████████████████████▋| 497/500 [1:20:09<00:23,  7.99s/it][I 2025-09-11 12:49:10,236] Trial 688 pruned.
# Overall Optimization Progress: 100%|██████████████████████████████████████████████▊| 498/500 [1:20:15<00:15,  7.57s/it][I 2025-09-11 12:49:23,596] Trial 689 finished with value: 0.002684060949832201 and parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 8.112122166240054e-05, 'dropout_trunk': 0.017554630114197785, 'learning_rate': 0.0017908967960292448, 'l2_reg_strength': 3.083552035046004e-05}. Best is trial 586 with value: 0.002001304179430008.
# Overall Optimization Progress: 100%|██████████████████████████████████████████████▉| 499/500 [1:20:29<00:09,  9.30s/it][I 2025-09-11 12:49:29,822] Trial 690 pruned.
# Overall Optimization Progress: 100%|███████████████████████████████████████████████| 500/500 [1:20:35<00:00,  9.67s/it]
# Best parameters: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.010328804765795407, 'dropout_trunk': 0.012896858273254937, 'learning_rate': 0.0015170963379851404, 'l2_reg_strength': 3.9720789390567614e-05}

# %% [markdown]
# ## Training

# %% [markdown]
# ## Opzione 1: training su training set + validation set per early stopping

# %% [raw]
# # ---------- Parametri early stopping "robusti" ----------
# max_epochs   = 5000 #20000          # come il tuo training originale
# es_warmup    = 2000           # epoche di warm-up prima di considerare early stopping
# patience     = 800            # quante epoche senza miglioramento dopo il warm-up
# check_every  = 5              # valida ogni N epoche (metti 1 se vuoi ogni epoca)
# rel_min_delta = 1e-3          # 0.1% di miglioramento richiesto
#
# class EarlyStopper:
#     def __init__(self, patience, min_delta_abs=0.0):
#         self.patience = patience
#         self.min_delta_abs = min_delta_abs
#         self.best = float("inf")
#         self.bad_epochs = 0
#
#     def step(self, val):
#         improved = val < (self.best - self.min_delta_abs)
#         if improved:
#             self.best = val
#             self.bad_epochs = 0
#         else:
#             self.bad_epochs += 1
#         return improved
#
#     def should_stop(self):
#         return self.bad_epochs >= self.patience
#
# early_stopper = EarlyStopper(patience=patience, min_delta_abs=0.0)
#
# train_losses, val_losses = [], []
# best_state_dict = None
# best_epoch = None
#
# for epoch in tqdm(range(1, max_epochs + 1), desc="Training"):
#     # -------- Train --------
#     model.train()
#     optimizer.zero_grad(set_to_none=True)
#     pred_tr = model(Xb_tr, Xt_tr)             # (B, N, 1)
#     loss_tr = loss_fn(pred_tr, Y_tr)
#     loss_tr.backward()
#     torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#     optimizer.step()
#
#     train_losses.append(float(loss_tr.detach().cpu()))
#
#     # -------- Validate ogni 'check_every' epoche --------
#     do_check = (epoch % check_every == 0) or (epoch == 1)
#     if do_check:
#         model.eval()
#         with torch.no_grad():
#             pred_va = model(Xb_va, Xt_va)
#             loss_va = loss_fn(pred_va, Y_va)
#         vl = float(loss_va.detach().cpu())
#         val_losses.append(vl)
#
#         # Riduci LR se in plateau (scheduler visto prima)
#         scheduler.step(vl)
#
#         # Imposta una soglia assoluta basata su miglioramento relativo richiesto
#         # (min_delta_abs = rel_min_delta * |best|)
#         current_min_delta_abs = rel_min_delta * (abs(early_stopper.best) if early_stopper.best < float("inf") else max(vl, 1.0))
#         early_stopper.min_delta_abs = current_min_delta_abs
#
#         # Durante il warm-up NON facciamo early stopping, ma salviamo il best
#         if epoch <= es_warmup:
#             # Aggiorna best se migliora
#             if vl < early_stopper.best - current_min_delta_abs:
#                 early_stopper.best = vl
#                 best_state_dict = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
#                 best_epoch = epoch
#         else:
#             # Dopo il warm-up, abilita early stopping vero e proprio
#             improved = early_stopper.step(vl)
#             if improved:
#                 best_state_dict = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
#                 best_epoch = epoch
#
#             if early_stopper.should_stop():
#                 print(f"\nEarly stopping: nessun miglioramento per {patience} epoche dopo il warm-up.")
#                 print(f"Miglior val a epoca {best_epoch}: {early_stopper.best:.6g}")
#                 break
#
# # ---------- Ripristina i pesi migliori ----------
# if best_state_dict is not None:
#     model.load_state_dict({k: v.to(device) for k, v in best_state_dict.items()})
#     torch.save(model.state_dict(), "best_model.pt")
#     print(f"Best model (val) salvato da epoca {best_epoch} in 'best_model.pt'")
# else:
#     print("Attenzione: non è stato salvato alcun best_state (controlla il loop).")
#
# # ---------- Plot (train/val) ----------
# plt.figure()
# plt.plot(train_losses, label="train")
# # allinea l'asse x della val con le epoche in cui è stata calcolata
# val_x = [i for i in range(1, len(train_losses)+1) if (i % check_every == 0) or (i == 1)]
# plt.plot(val_x[:len(val_losses)], val_losses, label="val")
# plt.xlabel("Epoch")
# plt.ylabel("MSE loss")
# plt.title("Training & Validation loss (ES con warm-up)")
# plt.grid(True); plt.legend(); plt.show()
#
# # ---------- Test con i migliori pesi ----------
# model.eval()
# with torch.no_grad():
#     Y_pred = model(Xb_te, Xt_te)
#     test_mse = torch.mean((Y_pred - Y_te) ** 2).item()
# print(f"Test MSE (best val weights): {test_mse:.6f}")

# %% [markdown]
# ## Opzione 2: training su training + validation set

# %%
import pickle
import torch
import torch.optim as optim
from torch import nn
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
from tqdm import tqdm

# ---------- 1) Carica i best params scelti su validation ----------
with open("best_params.pkl", "rb") as f:
    best_params = pickle.load(f)
print("Best params:", best_params)

# (handle activations saved as strings)
def _act_from_any(v):
    if isinstance(v, str):
        m = {"relu": nn.ReLU, "tanh": nn.Tanh, "gelu": nn.GELU}
        lv = v.lower()
        if lv in m: return m[lv]
    return v  # already a class/type

# ---------- 2) Prepara tensori: unisci TRAIN e VAL ----------
# NOTE: keep tensors on CPU; we'll move to device per-batch in the loop
Xb_tr = torch.tensor(branch_inputs_train, dtype=torch.float32)
Xt_tr = torch.tensor(trunk_inputs_train,  dtype=torch.float32)
Y_tr  = torch.tensor(outputs_train,       dtype=torch.float32)

Xb_va = torch.tensor(branch_inputs_val,   dtype=torch.float32)
Xt_va = torch.tensor(trunk_inputs_val,    dtype=torch.float32)
Y_va  = torch.tensor(outputs_val,         dtype=torch.float32)

# Assicura shape target (B, N, 1) per Y_tr/Y_va
if Y_tr.dim() == 2: Y_tr = Y_tr.unsqueeze(-1)
if Y_va.dim() == 2: Y_va = Y_va.unsqueeze(-1)

# Helper per portare Xt a (B, N, 1) nei casi comuni
def _make_Xt_3d(Xt, B_target, N_target):
    if Xt.dim() == 3 and Xt.size(0) == B_target and Xt.size(1) == N_target and Xt.size(2) == 1:
        return Xt
    if Xt.dim() == 2 and Xt.size(0) == B_target and Xt.size(1) == 1:
        return Xt.unsqueeze(1).repeat(1, N_target, 1)
    if Xt.dim() == 3 and Xt.size(0) == B_target and Xt.size(1) == 1 and Xt.size(2) == 1:
        return Xt.repeat(1, N_target, 1)
    if Xt.dim() == 1 and Xt.size(0) == N_target:
        return Xt.view(1, N_target, 1).repeat(B_target, 1, 1)
    if Xt.dim() == 2 and Xt.size(0) == N_target and Xt.size(1) == 1:
        return Xt.unsqueeze(0).repeat(B_target, 1, 1)
    if Xt.dim() == 2 and Xt.size(0) == B_target * N_target and Xt.size(1) == 1:
        return Xt.view(B_target, N_target, 1)
    if Xt.dim() == 3 and Xt.size(0) == B_target * N_target and Xt.size(1) == 1 and Xt.size(2) == 1:
        return Xt.view(B_target, N_target, 1)
    raise AssertionError(f"Xt shape {tuple(Xt.shape)} non compatibile con (B={B_target}, N={N_target}, 1).")

# Porta Xt_tr/Xt_va a (B, N, 1) PRIMA di concatenare
Xt_tr = _make_Xt_3d(Xt_tr, Xb_tr.size(0), Y_tr.size(1)).contiguous()
Xt_va = _make_Xt_3d(Xt_va, Xb_va.size(0), Y_va.size(1)).contiguous()

# concatena lungo la dimensione batch
Xb_full = torch.cat([Xb_tr, Xb_va], dim=0).contiguous()
Xt_full = torch.cat([Xt_tr, Xt_va], dim=0).contiguous()
Y_full  = torch.cat([Y_tr,  Y_va ], dim=0).contiguous()

# Assicura shape target (B, N, 1) per Y_full
if Y_full.dim() == 2:
    Y_full = Y_full.unsqueeze(-1)

# Test set (CPU) + shape fix
Xb_te = torch.tensor(branch_inputs_test, dtype=torch.float32)
Xt_te = torch.tensor(trunk_inputs_test,  dtype=torch.float32)
Y_te  = torch.tensor(outputs_test,       dtype=torch.float32)
if Y_te.dim() == 2:
    Y_te = Y_te.unsqueeze(-1)
Xt_te = _make_Xt_3d(Xt_te, Xb_te.size(0), Y_te.size(1)).contiguous()

##################################
def shape(name, t):
    print(f"{name:10s} -> {tuple(t.shape)}")

shape("Xb_tr", Xb_tr); shape("Xt_tr", Xt_tr); shape("Y_tr",  Y_tr)
shape("Xb_va", Xb_va); shape("Xt_va", Xt_va); shape("Y_va",  Y_va)
shape("Xb_full", Xb_full); shape("Xt_full", Xt_full); shape("Y_full",  Y_full)

# Verifica B uguali sulle tre
Bxb, Bxt, By = Xb_full.size(0), Xt_full.size(0), Y_full.size(0)
assert Bxb == Bxt == By, f"Batch mismatch: Xb={Bxb}, Xt={Bxt}, Y={By}"
#######################################################################

# ---------- 3) DataLoader (mini-batch; CPU tensors, pin if cuda) ----------
batch_size = 256  # puoi provare 128/256 se la GPU lo permette ############################## Control mini-batch size
pin_mem = (device.type == "cuda")
dataset = TensorDataset(Xb_full, Xt_full, Y_full)
loader  = DataLoader(dataset, batch_size=batch_size, shuffle=True,
                     drop_last=False, pin_memory=pin_mem, num_workers=0)

# ---------- 4) Modello con i best params ----------
model = DeepONet1dSep(
    in_size_branch=Xb_full.shape[1],
    interact_size=best_params["interact_size"],
    branch_width=best_params["branch_width"],
    branch_depth=best_params["branch_depth"],
    branch_activation=_act_from_any(best_params["branch_activation"]),
    branch_dropout=best_params["dropout_branch"],
    trunk_input_dim=1,
    trunk_width=best_params["trunk_width"],
    trunk_depth=best_params["trunk_depth"],
    trunk_activation=_act_from_any(best_params["trunk_activation"]),
    trunk_dropout=best_params["dropout_trunk"]
).to(device).float()

loss_fn   = nn.MSELoss()
optimizer = optim.Adam(model.parameters(),
                       lr=best_params["learning_rate"],
                       weight_decay=best_params["l2_reg_strength"])

# Facoltativo: riduci LR se la loss media d'epoca non scende
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min",
                                                 factor=0.5, patience=10, verbose=False)

# ---------- 5) Training (20k epoche, NO early stopping) ----------
max_epochs = 3000
epoch_losses = []

for epoch in tqdm(range(1, max_epochs + 1), desc="Final training (train+val, mini-batch)"):
    model.train()
    running = 0.0
    count   = 0

    for xb, xt, yy in loader:
        # move batch to device here
        xb = xb.to(device, non_blocking=True)
        xt = xt.to(device, non_blocking=True)
        yy = yy.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        pred = model(xb, xt)          # (B, N, 1)
        loss = loss_fn(pred, yy)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        running += float(loss.detach().cpu())
        count   += 1

    # loss media per epoca
    epoch_loss = running / max(1, count)
    epoch_losses.append(epoch_loss)

    # scheduler (opzionale)
    scheduler.step(epoch_loss)

# Salva i pesi finali dopo 20k epoche
torch.save(model.state_dict(), "final_model_train_plus_val_minibatch.pt")
print("Modello finale salvato in 'final_model_train_plus_val_minibatch.pt'")

# ---------- 6) Curva della loss ----------
plt.figure()
plt.plot(epoch_losses)
plt.xlabel("Epoch")
plt.ylabel("MSE loss (train∪val, minibatch)")
plt.title("Final training loss (mini-batch, no ES)")
plt.grid(True)
plt.show()

# ---------- 7) Valutazione su TEST ----------
model.eval()
with torch.no_grad():
    Y_pred = model(Xb_te.to(device, non_blocking=True),
                   Xt_te.to(device, non_blocking=True))
    test_mse = torch.mean((Y_pred - Y_te.to(device, non_blocking=True)) ** 2).item()
print(f"Test MSE (final model trained on train+val, minibatch): {test_mse:.6f}")
# Out:
# Best params: {'interact_size': 35, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 3, 'branch_activation': 'relu', 'trunk_activation': 'relu', 'dropout_branch': 0.010328804765795407, 'dropout_trunk': 0.012896858273254937, 'learning_rate': 0.0015170963379851404, 'l2_reg_strength': 3.9720789390567614e-05}
# Xb_tr      -> (1050, 1000)
# Xt_tr      -> (1050, 1000, 1)
# Y_tr       -> (1050, 1000, 1)
# Xb_va      -> (150, 1000)
# Xt_va      -> (150, 1000, 1)
# Y_va       -> (150, 1000, 1)
# Xb_full    -> (1200, 1000)
# Xt_full    -> (1200, 1000, 1)
# Y_full     -> (1200, 1000, 1)
# Final training (train+val, mini-batch): 100%|██████████████████████████████████████| 3000/3000 [13:18<00:00,  3.75it/s]
# Modello finale salvato in 'final_model_train_plus_val_minibatch.pt'
# Test MSE (final model trained on train+val, minibatch): 0.000640

# %% [raw]
# import pickle
# import torch
# import torch.optim as optim
# from torch import nn
# import matplotlib.pyplot as plt
# from tqdm import tqdm
#
# # Option to load the best parameters from Optuna or perform optimization if not loaded
# def load_best_params():
#     try:
#         with open("best_params.pkl", "rb") as f:
#             best_params = pickle.load(f)
#             print("Loaded best parameters from previous optimization.")
#             return best_params
#     except FileNotFoundError:
#         print("Best parameters file not found. Running Optuna optimization.")
#         study = optuna.create_study(direction="minimize")
#         study.optimize(objective, n_trials=50)
#         best_params = study.best_params
#         with open("best_params.pkl", "wb") as f:
#             pickle.dump(best_params, f)
#         print("Optimized parameters saved.")
#         return best_params
#
#
# # Load best parameters (if available)
# best_params = load_best_params()
#
# # Print best parameters before starting training
# print("Best parameters for training:")
# for key, value in best_params.items():
#     print(f"{key}: {value}")
#
# # Use the best parameters to set up the model
# # Use the best parameters to set up the model
# model = DeepONet1dSep(
#     in_size_branch=Xb_train.shape[1],
#     interact_size=best_params["interact_size"],
#     branch_width=best_params["branch_width"],
#     branch_depth=best_params["branch_depth"],
#     branch_activation=best_params["branch_activation"], #nn.Tanh
#     branch_dropout=best_params["dropout_branch"],
#     trunk_input_dim=1,
#     trunk_width=best_params["trunk_width"],
#     trunk_depth=best_params["trunk_depth"],
#     trunk_activation=best_params["trunk_activation"], #nn.ReLU
#     trunk_dropout=best_params["dropout_trunk"]
# ).to(device)
#
#
# # Prepare data
# Xb_train = torch.tensor(branch_inputs_train, dtype=torch.float32, device=device)
# Xt_train = torch.tensor(trunk_inputs_train, dtype=torch.float32, device=device)
# Y_train  = torch.tensor(outputs_train, dtype=torch.float32, device=device)
#
# Xb_test = torch.tensor(branch_inputs_test, dtype=torch.float32, device=device)
# Xt_test = torch.tensor(trunk_inputs_test, dtype=torch.float32, device=device)
# Y_test  = torch.tensor(outputs_test, dtype=torch.float32, device=device)
#
# # Ensure Y has shape (B, N, 1)
# if Y_train.dim() == 2:
#     Y_train = Y_train.unsqueeze(-1)
# if Y_test.dim() == 2:
#     Y_test = Y_test.unsqueeze(-1)
#
# # Use the best parameters to define the optimizer with L2 regularization
# optimizer = optim.Adam(model.parameters(), lr=best_params["learning_rate"], weight_decay=best_params["l2_reg_strength"])  # L2 regularization with weight_decay
# loss_fn = torch.nn.MSELoss()  # Use PyTorch's built-in MSELoss
#
# loss_history = []
# model.train()
# num_steps = 20_000
# for step in tqdm(range(num_steps)):
#     optimizer.zero_grad()
#     pred = model(Xb_train, Xt_train)  # (B, N, 1)
#     loss = loss_fn(pred, Y_train)
#     loss.backward()
#     optimizer.step()
#
#     loss_history.append(loss.detach().cpu().item())
#
# # Plot the loss history after training is done
# plt.plot(loss_history[100:])  # We remove the first 100 steps to better visualize the trend
# plt.xlabel("Step")
# plt.ylabel("MSE loss")
# plt.title("Training loss")
# plt.grid()
# plt.show()
#
# # Evaluate on the test set
# model.eval()
# with torch.no_grad():
#     Y_pred = model(Xb_test, Xt_test)
#     mse = torch.mean((Y_pred - Y_test)**2).item()
#
# print(f"Test MSE: {mse:.4f}")

# %%
#Zoom in
plt.plot(epoch_losses[2000:]) #We remove the first 18000 steps to better visualize the trend
plt.xlabel("Step")
plt.ylabel("MSE loss")
plt.title("Training loss")
plt.grid()
plt.show()

# %% [markdown]
# ## Test

# %%
model.eval()
with torch.no_grad():
    sample_idx = 10
    model_dev = next(model.parameters()).device  # cuda/cpu of the model

    # ---- branch sample (keep batch dim) ----
    xb_s = Xb_test[sample_idx:sample_idx+1].to(model_dev, non_blocking=True)  # (1, F)

    # ---- trunk sample (handle 2D or 3D, keep batch dim) ----
    if Xt_test.dim() == 2:  # (N,1)
        xt_s = Xt_test.unsqueeze(0).to(model_dev, non_blocking=True)          # (1, N, 1)
    elif Xt_test.dim() == 3:  # (B,N,1)
        xt_s = Xt_test[sample_idx:sample_idx+1].to(model_dev, non_blocking=True)  # (1, N, 1)
    else:
        raise RuntimeError(f"Unexpected Xt_test.dim()={Xt_test.dim()}")

    # ---- forward ----
    y_pred = model(xb_s, xt_s)          # (1, N, 1)
    y_pred_np = y_pred[0, :, 0].cpu().numpy()

    # ---- ground truth (ensure shape (N,)) ----
    y_gt = Y_test[sample_idx]
    if y_gt.dim() == 2:   # (N,1)
        y_gt_np = y_gt[:, 0].cpu().numpy()
    elif y_gt.dim() == 1: # (N,)
        y_gt_np = y_gt.cpu().numpy()
    else:
        y_gt_np = y_gt.squeeze().cpu().numpy()

    # ---- x-grid from trunk ----
    xgrid = xt_s[0, :, 0].detach().cpu().numpy()

    plt.plot(xgrid, y_gt_np, label="gt antiderivative")
    plt.plot(xgrid, y_pred_np, label="prediction")
    plt.title("Test sample comparison")
    plt.legend()
    plt.grid()
    plt.show()

# %%
import numpy as np
import torch

def normalized_l2_error(pred, ref):
    # pred/ref: (...,)
    diff = pred - ref
    diff_norm = torch.linalg.vector_norm(diff)
    ref_norm  = torch.linalg.vector_norm(ref)
    return (diff_norm / ref_norm).item()

model.eval()
with torch.no_grad():
    dev = next(model.parameters()).device

    # Move whole test set to the model's device
    xb = Xb_test.to(dev, non_blocking=True)               # (B, F)
    xt = Xt_test.to(dev, non_blocking=True)               # (N,1) or (B,N,1) — model will expand if needed
    y  = Y_test.to(dev, non_blocking=True)                # (B, N, 1) (or (B,N) if that’s your variant)

    # Forward once over the full test set
    pred = model(xb, xt)                                  # (B, N, 1)

    # Ensure both tensors are 2D (B, N) for error computation
    pred2 = pred.view(pred.size(0), -1)                   # (B, N)
    y2    = y.view(y.size(0), -1)                         # (B, N)

    # Vectorized normalized L2 per-sample
    num   = torch.linalg.vector_norm(pred2 - y2, dim=1)   # (B,)
    denom = torch.linalg.vector_norm(y2, dim=1).clamp_min(1e-12)
    errs  = (num / denom)                                 # (B,)

    mean_err = errs.mean().item()
    std_err  = errs.std(unbiased=False).item()

print(
    "Normalized L2 error over the test set (per-sample aggregation):\n"
    f"  mean = {mean_err:.6f}  ({mean_err*100:.2f}%)\n"
    f"  std  = {std_err:.6f}  ({std_err*100:.2f}%)\n"
    "Interpretation: 0 is perfect; 0.10 ≈ 10% relative error. Lower is better."
)
# Out:
# Normalized L2 error over the test set (per-sample aggregation):
#   mean = 0.025052  (2.51%)
#   std  = 0.042782  (4.28%)
# Interpretation: 0 is perfect; 0.10 ≈ 10% relative error. Lower is better.

# %% [markdown]
# ## Test: predict new data

# %%
# ========= Evaluation config =========
data_path    = "antiderivative_aligned_data.npz"   # or ..._test.npz / ..._train.npz
weights_path = "deeponet.pt"                       # your saved model state_dict

"""
# Must match the trained model:
in_size_branch = 100
width_size     = 40
depth          = 1
interact_size  = 40

# What to plot
plot_sample_indices = [0, 1, 2]

# Device preference: CUDA > MPS (Apple Silicon) > CPU
import torch
if torch.cuda.is_available():
    device = torch.device("cuda")
elif getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
device
"""
# Out:
# '\n# Must match the trained model:\nin_size_branch = 100\nwidth_size     = 40\ndepth          = 1\ninteract_size  = 40\n\n# What to plot\nplot_sample_indices = [0, 1, 2]\n\n# Device preference: CUDA > MPS (Apple Silicon) > CPU\nimport torch\nif torch.cuda.is_available():\n    device = torch.device("cuda")\nelif getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():\n    device = torch.device("mps")\nelse:\n    device = torch.device("cpu")\ndevice\n'

# %%
import numpy as np

npz = np.load(data_path, allow_pickle=True)
branch_inputs = npz["X"][0]    # (B, P)
trunk_inputs  = npz["X"][1]    # (N, 1) shared grid
y_true        = npz["y"]       # (B, N) or (B, N, 1)

print("Loaded shapes:", branch_inputs.shape, trunk_inputs.shape, y_true.shape)

# Ensure y_true is (B, N, 1)
if y_true.ndim == 2:
    y_true = y_true[..., None]
elif y_true.ndim == 3 and y_true.shape[-1] == 1:
    pass
else:
    raise ValueError(f"Unexpected y shape: {y_true.shape}")

import torch
Xb = torch.tensor(branch_inputs, dtype=torch.float32, device=device)   # (B, P)
Xt = torch.tensor(trunk_inputs,  dtype=torch.float32, device=device)   # (N, 1)
Y  = torch.tensor(y_true,        dtype=torch.float32, device=device)   # (B, N, 1)

# Expand shared trunk grid to batch: (B, N, 1)
Xt_batch = Xt.unsqueeze(0).expand(Xb.shape[0], -1, -1)
# Out:
# Loaded shapes: (150, 1000) (1000, 1) (150, 1000)

# %%
print("Xb shape:", Xb.shape)         # should be (B, P) only
print("Xt shape:", Xt.shape)         # (N, 1)
try:
    print("Xt_batch shape:", Xt_batch.shape)  # (B, N, 1)
except NameError:
    pass

# What the trained model expects
branch_in_expected = model.branch_net.net[0].in_features
trunk_in_expected  = model.trunk_net.net[0].in_features
print("Model expects: branch_in =", branch_in_expected, "  trunk_in =", trunk_in_expected)

# If you previously did something like: Xb = Xb.unsqueeze(1).expand(B,N,P) — undo it.
if Xb.ndim > 2:
    # collapse any extra dims except the last one (features)
    Xb = Xb.view(Xb.shape[0], -1)  # but better: rebuild from the original branch_inputs array
    print("Fixed Xb to shape:", Xb.shape)

# Xt should be shared grid: (N,1)
# Build Xt_batch for the model call as (B,N,1), but DO NOT touch Xb
Xt_batch = Xt.unsqueeze(0).expand(Xb.shape[0], -1, -1)
print("Xt_batch shape:", Xt_batch.shape)

import numpy as np
import torch

P_data = Xb.shape[1]
P_tgt  = branch_in_expected

if P_data != P_tgt:
    # assume branch and trunk share the same interval; infer from Xt
    a = float(Xt[0,0].cpu().item())
    b = float(Xt[-1,0].cpu().item())
    x_src = np.linspace(a, b, P_data)
    x_tgt = np.linspace(a, b, P_tgt)

    Xb_np = Xb.detach().cpu().numpy()
    Xb_rs = np.stack([np.interp(x_tgt, x_src, row) for row in Xb_np], axis=0)  # (B, P_tgt)
    Xb = torch.tensor(Xb_rs, dtype=torch.float32, device=Xb.device)
    print(f"Resampled branch from P={P_data} -> P={P_tgt}")
# Out:
# Xb shape: torch.Size([150, 1000])
# Xt shape: torch.Size([1000, 1])
# Xt_batch shape: torch.Size([150, 1000, 1])
# Model expects: branch_in = 1000   trunk_in = 1
# Xt_batch shape: torch.Size([150, 1000, 1])

# %%
import torch

def normalized_l2_error(pred, ref):
    diff = pred - ref
    diff_norm = torch.linalg.vector_norm(diff)
    ref_norm  = torch.linalg.vector_norm(ref)
    return (diff_norm / (ref_norm + 1e-12)).item()

with torch.no_grad():
    Y_pred = model(Xb, Xt_batch)   # (B, N, 1)

B, N, _ = Y.shape
errs, mses = [], []
for i in range(B):
    errs.append(normalized_l2_error(Y_pred[i].view(-1), Y[i].view(-1)))
    mses.append(torch.mean((Y_pred[i] - Y[i])**2).item())

import numpy as np
print(f"Mean norm L2 error: {np.mean(errs):.6e}  (std {np.std(errs):.6e})")
print(f"Mean MSE:           {np.mean(mses):.6e}  (std {np.std(mses):.6e})")
# Out:
# Mean norm L2 error: 1.992648e-01  (std 1.382862e-01)
# Mean MSE:           1.407530e-04  (std 1.101259e-04)

# %%
import matplotlib.pyplot as plt

xgrid = Xt[:, 0].detach().cpu().numpy()  # (N,)

plot_sample_indices = [0, 1, 2]

for idx in plot_sample_indices:
    if not (0 <= idx < B):
        continue
    y_gt  = Y[idx, :, 0].detach().cpu().numpy()
    y_hat = Y_pred[idx, :, 0].detach().cpu().numpy()
    plt.figure()
    plt.plot(xgrid, y_gt,  label="ground truth")
    plt.plot(xgrid, y_hat, label="prediction")
    plt.title(f"Sample {idx} | normL2={errs[idx]:.3e} | MSE={mses[idx]:.3e}")
    plt.xlabel("x"); plt.ylabel("∫ u(s) ds")
    plt.grid(); plt.legend()
    plt.show()

# %% [markdown]
# ### Trial (normalization)

# %%
# ========= Evaluation config =========
data_path    = "antiderivative_aligned_data.npz"   # or ..._test.npz / ..._train.npz
weights_path = "deeponet.pt"

import numpy as np
import torch
import matplotlib.pyplot as plt

# -- Load dataset
npz = np.load(data_path, allow_pickle=True)
branch_inputs = npz["X"][0]    # (B, P)
trunk_inputs  = npz["X"][1]    # (N, 1) shared grid
y_true        = npz["y"]       # (B, N) or (B, N, 1)

print("Loaded shapes:", branch_inputs.shape, trunk_inputs.shape, y_true.shape)

# Ensure y_true has shape (B, N, 1)
if y_true.ndim == 2:
    y_true = y_true[..., None]
elif not (y_true.ndim == 3 and y_true.shape[-1] == 1):
    raise ValueError(f"Unexpected y shape: {y_true.shape}")

# ----- Normalize ONLY the input functions (branch) -----
# per-sample normalization by max|u|
eps = 1e-12
amp_branch = np.maximum(np.max(np.abs(branch_inputs), axis=1, keepdims=True), eps)  # (B,1)
branch_inputs_norm = branch_inputs / amp_branch                                    # (B,P)

# ----- Tensors -----
Xb = torch.tensor(branch_inputs_norm, dtype=torch.float32, device=device)  # normalized input (B,P)
Xt = torch.tensor(trunk_inputs,        dtype=torch.float32, device=device)  # (N,1)
Y  = torch.tensor(y_true,              dtype=torch.float32, device=device)  # ground truth (B,N,1)

# Expand shared trunk grid to batch: (B,N,1)
Xt_batch = Xt.unsqueeze(0).expand(Xb.shape[0], -1, -1)

# Resample branch if needed
branch_in_expected = model.branch_net.net[0].in_features
if Xb.shape[1] != branch_in_expected:
    a = float(Xt[0,0].detach().cpu().item())
    b = float(Xt[-1,0].detach().cpu().item())
    x_src = np.linspace(a, b, Xb.shape[1])
    x_tgt = np.linspace(a, b, branch_in_expected)
    Xb_np = Xb.detach().cpu().numpy()
    Xb_rs = np.stack([np.interp(x_tgt, x_src, row) for row in Xb_np], axis=0)  # (B, P_target)
    Xb = torch.tensor(Xb_rs, dtype=torch.float32, device=Xb.device)
    print(f"[EVAL] Resampled branch P: {Xb_np.shape[1]} -> {branch_in_expected}")

# ----- Inference (outputs are NOT normalized) -----
with torch.no_grad():
    Y_pred = model(Xb, Xt_batch)   # (B,N,1)

# ----- Metrics -----
def normalized_l2_error(pred, ref):
    diff = pred - ref
    diff_norm = torch.linalg.vector_norm(diff)
    ref_norm  = torch.linalg.vector_norm(ref)
    return (diff_norm / (ref_norm + 1e-12)).item()

B, N, _ = Y.shape
errs, mses = [], []
for i in range(B):
    errs.append(normalized_l2_error(Y_pred[i].view(-1), Y[i].view(-1)))
    mses.append(torch.mean((Y_pred[i] - Y[i])**2).item())

print(f"Mean norm L2 error: {np.mean(errs):.6e}  (std {np.std(errs):.6e})")
print(f"Mean MSE:           {np.mean(mses):.6e}  (std {np.std(mses):.6e})")

# ----- Plot -----
xgrid = Xt[:, 0].detach().cpu().numpy()
plot_sample_indices = [0, 1, 2]

for idx in plot_sample_indices:
    if not (0 <= idx < B):
        continue
    y_gt  = Y[idx, :, 0].detach().cpu().numpy()
    y_hat = Y_pred[idx, :, 0].detach().cpu().numpy()
    plt.figure()
    plt.plot(xgrid, y_gt,  label="ground truth")
    plt.plot(xgrid, y_hat, label="prediction")
    plt.title(f"Sample {idx} | normL2={errs[idx]:.3e} | MSE={mses[idx]:.3e}")
    plt.xlabel("x"); plt.ylabel("∫ u(s) ds")
    plt.grid(); plt.legend()
    plt.show()
# Out:
# Loaded shapes: (150, 1000) (1000, 1) (150, 1000)
# Mean norm L2 error: 4.066413e-01  (std 1.762493e-01)
# Mean MSE:           1.220475e-03  (std 2.037666e-03)
