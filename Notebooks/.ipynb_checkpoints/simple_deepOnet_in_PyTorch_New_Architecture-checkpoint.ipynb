# %% [markdown]
# # DeepONet Tutorial in PyTorch
#
# This notebook is a PyTorch reimplementation of a simple 1D DeepONet originally written in JAX/Equinox.
# It learns the antiderivative operator from pairs $(u(x), x)$ to $\int_0^x u(s) ds$ using the aligned dataset from DeepXDE.
#
# **What changes vs JAX version**
# - Uses `torch.nn` modules for the branch/trunk MLPs and a learnable scalar bias.
# - Uses `torch.optim.Adam` with a standard manual training loop.
# - Replaces `jax.vmap` with batched tensor operations.
# - Keeps plots and evaluation identical where possible.

# %% [markdown]
# A DeepONet is a deep learning architecture to evaluate a *nonlinear operator*
# applied to a discretized input field/function at an arbitrary query point. This
# can, for instance, be used to learn solutions to a family of parametric PDEs
# which can then be queried at arbitrary points in space (and time).
#
# Examples of operator mappings:
#
# * From initial condition to solution field at a later time
# * From the parameter field (e.g. space-dependent diffusion coefficient) to the
#   solution field
#
# The DeepONet does not return the full output field, but allows us to query it at
# arbitrary points.
#
# Following the tutorial of
# [DeepXDE](https://deepxde.readthedocs.io/en/latest/demos/operator/antiderivative_aligned.html),
# this video is concered with **learning the 1d antiderivative operator**, defined by the ODE
#
# $$
# \begin{cases}
# \frac{d v}{d x} &= u(x) \quad & x \in [0, 1]
# \\
# v(0) &= 0
# \end{cases}
# $$
#
# For this, we discretize the domain $\Omega = [0, 1]$ into $m=100$ degrees of
# freedom at which we evaluate $u(x)$. Then, the DeepONet $G_\theta$ takes this
# $100$-dimensional vector and a one-dimensional query coordinate to evaluate
# $v(x)$ at this query point.
#
# $$
# \begin{aligned}
# G_\theta : \mathbb{R}^m \times \mathbb{R}^1 \mapsto \mathbb{R}
# \end{aligned}
# $$

# %% [markdown]
# ![deeponet_architecture](deeponet_architecture.png)

# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
#from tqdm.autonotebook import tqdm
from tqdm import tqdm

# Prefer CUDA if available, else MPS (Apple Silicon), else CPU
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

device
# Out:
# device(type='cuda')

# %%
# Dataset courtesy of DeepXDE (Lu et al.).
# Original JAX notebook downloaded from ETH Zurich course materials.
# We'll fetch the same training/test sets used there.
#!wget -q -O antiderivative_aligned_train.npz https://github.com/mroberto166/CAMLab-DLSCTutorials/raw/main/antiderivative_aligned_train.npz
#!wget -q -O antiderivative_aligned_test.npz  https://github.com/mroberto166/CAMLab-DLSCTutorials/raw/main/antiderivative_aligned_test.npz

train_npz = np.load("antiderivative_aligned_train.npz", allow_pickle=True)
test_npz  = np.load("antiderivative_aligned_test.npz", allow_pickle=True)

branch_inputs_train = train_npz["X"][0]   # (N_train, in_size_branch)
trunk_inputs_train  = train_npz["X"][1]   # (N_train, N_grid, 1)
outputs_train       = train_npz["y"]      # (N_train, N_grid, 1)

branch_inputs_test = test_npz["X"][0]
trunk_inputs_test  = test_npz["X"][1]
outputs_test       = test_npz["y"]

branch_inputs_train.shape, trunk_inputs_train.shape, outputs_train.shape
# Out:
# ((360, 300), (300, 1), (360, 300))

# %%
f_idx=2 #index of the function to plot
plt.plot(trunk_inputs_train[:, 0], branch_inputs_train[f_idx, :], label="input u(x)")
plt.plot(trunk_inputs_train[:, 0], outputs_train[f_idx, :], label="∫ u ds (gt)")
plt.grid()
plt.legend()
plt.title("Sample training pair (aligned grid)")
plt.show()

# %%
class MLP(nn.Module):
    def __init__(self, in_size, out_size, width_size, depth, activation=nn.ReLU):
        super().__init__()
        layers = []
        last = in_size
        for _ in range(depth):
            layers.append(nn.Linear(last, width_size))
            layers.append(activation())
            last = width_size
        layers.append(nn.Linear(last, out_size))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

class DeepONet1dSep(nn.Module):
    def __init__(
        self,
        in_size_branch: int,
        interact_size: int,            # P' must match for branch & trunk
        # branch hyperparams
        branch_width: int = 40,
        branch_depth: int = 2,
        branch_activation: nn.Module = nn.ReLU,
        # trunk hyperparams
        trunk_input_dim: int = 1,
        trunk_width: int = 40,
        trunk_depth: int = 2,
        trunk_activation: nn.Module = nn.Tanh,  # smoothness w.r.t. x
    ):
        super().__init__()
        self.branch_net = MLP(
            in_size=in_size_branch,
            out_size=interact_size,
            width_size=branch_width,
            depth=branch_depth,
            activation=branch_activation,
        )
        self.trunk_net = MLP(
            in_size=trunk_input_dim,
            out_size=interact_size,
            width_size=trunk_width,
            depth=trunk_depth,
            activation=trunk_activation,
        )
        self.bias = nn.Parameter(torch.zeros(1))

    def forward(self, x_branch, x_trunk):
        """
        x_branch: (B, P) or (P,)
        x_trunk:  (N,1) or (B, N) or (B, N, 1)
        returns:  (B, N, 1) or (N, 1) if single-sample
        """
        single_sample = False
        if x_branch.dim() == 1:
            x_branch = x_branch.unsqueeze(0)  # (1, P)
            single_sample = True

        # Normalize x_trunk to (B, N, 1)
        if x_trunk.dim() == 1:
            x_trunk = x_trunk.unsqueeze(-1)                # (N,) -> (N,1)
        if x_trunk.dim() == 2:
            if x_trunk.size(-1) != 1:                      # (B,N) -> (B,N,1)
                x_trunk = x_trunk.unsqueeze(-1)
            else:                                          # (N,1) -> (B,N,1)
                x_trunk = x_trunk.unsqueeze(0).expand(x_branch.size(0), -1, -1)
        elif x_trunk.dim() == 3 and x_trunk.size(0) == 1 and x_branch.size(0) > 1:
            x_trunk = x_trunk.expand(x_branch.size(0), -1, -1)

        B, N, _ = x_trunk.shape
        bfeat = self.branch_net(x_branch)                        # (B, P')
        tfeat = self.trunk_net(x_trunk.reshape(B * N, -1))       # (B*N, P')
        tfeat = tfeat.view(B, N, -1)                             # (B, N, P')
        out = (bfeat.unsqueeze(1) * tfeat).sum(dim=-1, keepdim=True) + self.bias.view(1, 1, 1)
        if single_sample:
            out = out.squeeze(0)  # (N,1)
        return out

# %% [markdown]
# ## Hyperparameter optimization

# %%
import torch
import optuna
import torch.optim as optim
from torch import nn
from tqdm import tqdm  # Import tqdm for progress bar

# Ensure your training and testing data are loaded here
# Example (adjust as needed based on your dataset):
Xb_train = torch.tensor(branch_inputs_train, dtype=torch.float32, device=device)  # (N_train, in_size_branch)
Xt_train = torch.tensor(trunk_inputs_train,  dtype=torch.float32, device=device)  # (N_train, N_grid, 1)
Y_train = torch.tensor(outputs_train, dtype=torch.float32, device=device)  # (N_train, N_grid, 1)

Xb_test = torch.tensor(branch_inputs_test, dtype=torch.float32, device=device)  # (N_test, in_size_branch)
Xt_test = torch.tensor(trunk_inputs_test,  dtype=torch.float32, device=device)  # (N_test, N_grid, 1)
Y_test = torch.tensor(outputs_test, dtype=torch.float32, device=device)  # (N_test, N_grid, 1)

# Ensure Y_train and Y_test have the shape (B, N, 1)
if Y_train.dim() == 2:
    Y_train = Y_train.unsqueeze(-1)  # (N_train, N_grid) -> (N_train, N_grid, 1)
if Y_test.dim() == 2:
    Y_test = Y_test.unsqueeze(-1)  # (N_test, N_grid) -> (N_test, N_grid, 1)

# Define the objective function for Optuna's optimization
def objective(trial: optuna.Trial):
    # Hyperparameters to optimize
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
    branch_activation = trial.suggest_categorical("branch_activation", [nn.ReLU, nn.Tanh, nn.GELU])
    trunk_activation = trial.suggest_categorical("trunk_activation", [nn.ReLU, nn.Tanh, nn.GELU])
    branch_width = trial.suggest_int("branch_width", 10, 200, step=30)
    branch_depth = trial.suggest_int("branch_depth", 1, 5)
    trunk_width = trial.suggest_int("trunk_width", 10, 200, step=30)
    trunk_depth = trial.suggest_int("trunk_depth", 1, 5)
    interact_size = trial.suggest_int("interact_size", 5, 100, step=30)

    # Model setup with the current trial hyperparameters
    model = DeepONet1dSep(
        in_size_branch=Xb_train.shape[1],  # Pass the branch input size dynamically
        interact_size=interact_size,
        branch_width=branch_width,
        branch_depth=branch_depth,
        branch_activation=branch_activation,
        trunk_input_dim=1,
        trunk_width=trunk_width,
        trunk_depth=trunk_depth,
        trunk_activation=trunk_activation
    ).to(device)

    # Optimizer setup
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Training loop with tqdm for a cleaner progress bar
    model.train()
    num_epochs = 10
    for epoch in range(num_epochs):
        optimizer.zero_grad()
        outputs = model(Xb_train, Xt_train)
        loss = torch.mean((outputs - Y_train)**2)
        loss.backward()
        optimizer.step()

    # Evaluate the model on validation/test set
    model.eval()
    with torch.no_grad():
        Y_pred = model(Xb_test, Xt_test)
        mse = torch.mean((Y_pred - Y_test)**2).item()

    # Return MSE as the objective value to minimize
    return mse

# Create Optuna study and optimize the objective function with a tqdm progress bar for the entire optimization process
study = optuna.create_study(direction="minimize")

# Use tqdm for overall progress bar across all trials
n_trials = 50
with tqdm(total=n_trials, desc="Overall Optimization Progress", position=0, leave=True) as pbar:
    def tqdm_callback(study, trial):
        pbar.update(1)  # Update the progress bar after each trial

    # You can resume optimization if there is a stored study
    study.optimize(objective, n_trials=n_trials, callbacks=[tqdm_callback])

# Save the best parameters found
best_params = study.best_params
print(f"Best parameters: {best_params}")

# Save best parameters to a file
import pickle
with open("best_params.pkl", "wb") as f:
    pickle.dump(best_params, f)
# Out:
# [I 2025-09-07 12:59:25,505] A new study created in memory with name: no-name-9b4c27ca-2990-4f1b-a632-cf73a9375219
# Overall Optimization Progress:   0%|                                                            | 0/50 [00:00<?, ?it/s]C:\Users\piero\AppData\Local\Temp\ipykernel_5508\3991717190.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# C:\Users\piero\.conda\envs\deep_env1\lib\site-packages\optuna\distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains <class 'torch.nn.modules.activation.GELU'> which is of type type.
#   warnings.warn(message)
# [I 2025-09-07 12:59:25,799] Trial 0 finished with value: 0.01832687482237816 and parameters: {'learning_rate': 0.0008898380892557609, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 1, 'trunk_width': 130, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:   2%|█                                                   | 1/50 [00:00<00:14,  3.40it/s][I 2025-09-07 12:59:25,880] Trial 1 finished with value: 0.1332291215658188 and parameters: {'learning_rate': 0.00012975130251914133, 'branch_activation': <class 'torch.nn.modules.activation.GELU'>, 'trunk_activation': <class 'torch.nn.modules.activation.GELU'>, 'branch_width': 10, 'branch_depth': 1, 'trunk_width': 130, 'trunk_depth': 2, 'interact_size': 5}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:25,934] Trial 2 finished with value: 0.0247638076543808 and parameters: {'learning_rate': 0.0016419919244151187, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 40, 'branch_depth': 5, 'trunk_width': 70, 'trunk_depth': 1, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:   6%|███                                                 | 3/50 [00:00<00:05,  7.92it/s][I 2025-09-07 12:59:26,018] Trial 3 finished with value: 0.028449708595871925 and parameters: {'learning_rate': 0.00027791394834668815, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 100, 'branch_depth': 1, 'trunk_width': 70, 'trunk_depth': 3, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:26,184] Trial 4 finished with value: 0.051007140427827835 and parameters: {'learning_rate': 0.0003106904109946236, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.GELU'>, 'branch_width': 40, 'branch_depth': 2, 'trunk_width': 10, 'trunk_depth': 5, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  10%|█████▏                                              | 5/50 [00:00<00:05,  7.96it/s][I 2025-09-07 12:59:26,297] Trial 5 finished with value: 0.02789878658950329 and parameters: {'learning_rate': 0.005722244214766147, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 100, 'branch_depth': 3, 'trunk_width': 10, 'trunk_depth': 1, 'interact_size': 35}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  12%|██████▏                                             | 6/50 [00:00<00:05,  8.17it/s][I 2025-09-07 12:59:26,418] Trial 6 finished with value: 0.019895581528544426 and parameters: {'learning_rate': 0.0015256731866459085, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 100, 'trunk_depth': 5, 'interact_size': 5}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  14%|███████▎                                            | 7/50 [00:00<00:05,  8.23it/s][I 2025-09-07 12:59:26,491] Trial 7 finished with value: 0.0809725821018219 and parameters: {'learning_rate': 0.006782157920077813, 'branch_activation': <class 'torch.nn.modules.activation.GELU'>, 'trunk_activation': <class 'torch.nn.modules.activation.GELU'>, 'branch_width': 160, 'branch_depth': 3, 'trunk_width': 10, 'trunk_depth': 2, 'interact_size': 35}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:26,600] Trial 8 finished with value: 0.8109099864959717 and parameters: {'learning_rate': 1.0113613229918814e-05, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 40, 'branch_depth': 1, 'trunk_width': 190, 'trunk_depth': 1, 'interact_size': 35}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  18%|█████████▎                                          | 9/50 [00:01<00:04,  9.23it/s][I 2025-09-07 12:59:26,678] Trial 9 finished with value: 0.03858749568462372 and parameters: {'learning_rate': 0.0068306264438478025, 'branch_activation': <class 'torch.nn.modules.activation.GELU'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 40, 'branch_depth': 3, 'trunk_width': 100, 'trunk_depth': 2, 'interact_size': 5}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:26,923] Trial 10 finished with value: 0.14937277138233185 and parameters: {'learning_rate': 3.1325188942269934e-05, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 130, 'branch_depth': 5, 'trunk_width': 190, 'trunk_depth': 4, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  22%|███████████▏                                       | 11/50 [00:01<00:05,  7.79it/s][I 2025-09-07 12:59:27,117] Trial 11 finished with value: 0.04228725656867027 and parameters: {'learning_rate': 0.0013212032824818718, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 190, 'branch_depth': 2, 'trunk_width': 130, 'trunk_depth': 5, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  24%|████████████▏                                      | 12/50 [00:01<00:05,  7.01it/s][I 2025-09-07 12:59:27,280] Trial 12 finished with value: 0.028835734352469444 and parameters: {'learning_rate': 0.0014171096106203912, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 130, 'branch_depth': 2, 'trunk_width': 130, 'trunk_depth': 4, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  26%|█████████████▎                                     | 13/50 [00:01<00:05,  6.75it/s][I 2025-09-07 12:59:27,424] Trial 13 finished with value: 0.032981809228658676 and parameters: {'learning_rate': 0.0008628568647407536, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 190, 'branch_depth': 1, 'trunk_width': 160, 'trunk_depth': 3, 'interact_size': 5}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  28%|██████████████▎                                    | 14/50 [00:01<00:05,  6.79it/s][I 2025-09-07 12:59:27,540] Trial 14 finished with value: 0.07362572848796844 and parameters: {'learning_rate': 8.939609113985734e-05, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 130, 'branch_depth': 4, 'trunk_width': 70, 'trunk_depth': 4, 'interact_size': 35}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  30%|███████████████▎                                   | 15/50 [00:02<00:04,  7.23it/s][I 2025-09-07 12:59:27,648] Trial 15 finished with value: 0.030580556020140648 and parameters: {'learning_rate': 0.0006303238639882055, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 70, 'branch_depth': 2, 'trunk_width': 100, 'trunk_depth': 3, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  32%|████████████████▎                                  | 16/50 [00:02<00:04,  7.70it/s][I 2025-09-07 12:59:27,861] Trial 16 finished with value: 0.09447874873876572 and parameters: {'learning_rate': 0.0028757634968884574, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 160, 'trunk_depth': 5, 'interact_size': 5}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  34%|█████████████████▎                                 | 17/50 [00:02<00:05,  6.51it/s][I 2025-09-07 12:59:28,005] Trial 17 finished with value: 0.03333977982401848 and parameters: {'learning_rate': 0.0005124308607569508, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 70, 'branch_depth': 4, 'trunk_width': 40, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  36%|██████████████████▎                                | 18/50 [00:02<00:04,  6.63it/s][I 2025-09-07 12:59:28,190] Trial 18 finished with value: 0.03195757418870926 and parameters: {'learning_rate': 0.0028809578462749568, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 160, 'branch_depth': 2, 'trunk_width': 160, 'trunk_depth': 4, 'interact_size': 35}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  38%|███████████████████▍                               | 19/50 [00:02<00:04,  6.23it/s][I 2025-09-07 12:59:28,290] Trial 19 finished with value: 0.037446409463882446 and parameters: {'learning_rate': 0.00018100151150176892, 'branch_activation': <class 'torch.nn.modules.activation.GELU'>, 'trunk_activation': <class 'torch.nn.modules.activation.GELU'>, 'branch_width': 70, 'branch_depth': 1, 'trunk_width': 100, 'trunk_depth': 2, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:28,451] Trial 20 finished with value: 0.029912415891885757 and parameters: {'learning_rate': 0.0031084426374372383, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 3, 'trunk_width': 130, 'trunk_depth': 3, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  42%|█████████████████████▍                             | 21/50 [00:02<00:04,  6.81it/s][I 2025-09-07 12:59:28,534] Trial 21 finished with value: 0.025216873735189438 and parameters: {'learning_rate': 0.0016146591863349352, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 70, 'branch_depth': 5, 'trunk_width': 70, 'trunk_depth': 1, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:28,649] Trial 22 finished with value: 0.045353226363658905 and parameters: {'learning_rate': 0.0008058914507547692, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 10, 'branch_depth': 4, 'trunk_width': 40, 'trunk_depth': 1, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  46%|███████████████████████▍                           | 23/50 [00:03<00:03,  7.82it/s][I 2025-09-07 12:59:28,800] Trial 23 finished with value: 0.02759450674057007 and parameters: {'learning_rate': 0.0020732784397272585, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 5, 'trunk_width': 70, 'trunk_depth': 1, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  48%|████████████████████████▍                          | 24/50 [00:03<00:03,  7.50it/s][I 2025-09-07 12:59:28,924] Trial 24 finished with value: 0.06810248643159866 and parameters: {'learning_rate': 0.00045457128270174935, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 10, 'branch_depth': 4, 'trunk_width': 100, 'trunk_depth': 2, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  50%|█████████████████████████▌                         | 25/50 [00:03<00:03,  7.65it/s][I 2025-09-07 12:59:28,968] Trial 25 finished with value: 0.028978504240512848 and parameters: {'learning_rate': 0.003917839310919827, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 190, 'branch_depth': 2, 'trunk_width': 40, 'trunk_depth': 1, 'interact_size': 35}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:29,071] Trial 26 finished with value: 0.13186180591583252 and parameters: {'learning_rate': 0.009498891989857481, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 40, 'branch_depth': 1, 'trunk_width': 100, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  54%|███████████████████████████▌                       | 27/50 [00:03<00:02,  9.31it/s][I 2025-09-07 12:59:29,214] Trial 27 finished with value: 0.02642999403178692 and parameters: {'learning_rate': 0.0010757906108993633, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 130, 'branch_depth': 5, 'trunk_width': 130, 'trunk_depth': 3, 'interact_size': 5}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  56%|████████████████████████████▌                      | 28/50 [00:03<00:02,  8.61it/s][I 2025-09-07 12:59:29,322] Trial 28 finished with value: 0.07939395308494568 and parameters: {'learning_rate': 7.507137275350718e-05, 'branch_activation': <class 'torch.nn.modules.activation.GELU'>, 'trunk_activation': <class 'torch.nn.modules.activation.GELU'>, 'branch_width': 160, 'branch_depth': 3, 'trunk_width': 70, 'trunk_depth': 1, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  58%|█████████████████████████████▌                     | 29/50 [00:03<00:02,  8.78it/s][I 2025-09-07 12:59:29,434] Trial 29 finished with value: 0.08725276589393616 and parameters: {'learning_rate': 0.00019518870513458918, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 10, 'branch_depth': 1, 'trunk_width': 160, 'trunk_depth': 2, 'interact_size': 5}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  60%|██████████████████████████████▌                    | 30/50 [00:03<00:02,  8.81it/s][I 2025-09-07 12:59:29,563] Trial 30 finished with value: 0.047516655176877975 and parameters: {'learning_rate': 0.0018651297228586983, 'branch_activation': <class 'torch.nn.modules.activation.GELU'>, 'trunk_activation': <class 'torch.nn.modules.activation.GELU'>, 'branch_width': 70, 'branch_depth': 2, 'trunk_width': 40, 'trunk_depth': 5, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  62%|███████████████████████████████▌                   | 31/50 [00:04<00:02,  8.51it/s][I 2025-09-07 12:59:29,680] Trial 31 finished with value: 0.020158780738711357 and parameters: {'learning_rate': 0.0018823752223624392, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 70, 'branch_depth': 5, 'trunk_width': 70, 'trunk_depth': 1, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  64%|████████████████████████████████▋                  | 32/50 [00:04<00:02,  8.55it/s][I 2025-09-07 12:59:29,762] Trial 32 finished with value: 0.020791679620742798 and parameters: {'learning_rate': 0.0009467182032467936, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 5, 'trunk_width': 70, 'trunk_depth': 1, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:29,810] Trial 33 finished with value: 0.021973473951220512 and parameters: {'learning_rate': 0.00041198192319050116, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 4, 'trunk_width': 100, 'trunk_depth': 1, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  68%|██████████████████████████████████▋                | 34/50 [00:04<00:01, 10.63it/s][I 2025-09-07 12:59:29,927] Trial 34 finished with value: 0.019187789410352707 and parameters: {'learning_rate': 0.000782921283180936, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 5, 'trunk_width': 70, 'trunk_depth': 2, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:30,018] Trial 35 finished with value: 0.02464435063302517 and parameters: {'learning_rate': 0.0006313927323989868, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 5, 'trunk_width': 130, 'trunk_depth': 2, 'interact_size': 35}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  72%|████████████████████████████████████▋              | 36/50 [00:04<00:01, 10.13it/s][I 2025-09-07 12:59:30,084] Trial 36 finished with value: 0.018371885642409325 and parameters: {'learning_rate': 0.0022250202526888883, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 130, 'branch_depth': 4, 'trunk_width': 40, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:30,202] Trial 37 finished with value: 0.046467654407024384 and parameters: {'learning_rate': 0.0043568208754701885, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 130, 'branch_depth': 4, 'trunk_width': 40, 'trunk_depth': 3, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  76%|██████████████████████████████████████▊            | 38/50 [00:04<00:01, 10.41it/s][I 2025-09-07 12:59:30,319] Trial 38 finished with value: 0.0492626316845417 and parameters: {'learning_rate': 0.00029560576589937403, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 130, 'branch_depth': 4, 'trunk_width': 10, 'trunk_depth': 3, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:30,446] Trial 39 finished with value: 0.4856187105178833 and parameters: {'learning_rate': 0.0026589055954080866, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 160, 'branch_depth': 1, 'trunk_width': 10, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  80%|████████████████████████████████████████▊          | 40/50 [00:04<00:01,  9.58it/s][I 2025-09-07 12:59:30,533] Trial 40 finished with value: 0.02016856148838997 and parameters: {'learning_rate': 0.0011651237722991564, 'branch_activation': <class 'torch.nn.modules.activation.GELU'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 190, 'branch_depth': 3, 'trunk_width': 40, 'trunk_depth': 3, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:30,676] Trial 41 finished with value: 0.025369049981236458 and parameters: {'learning_rate': 0.0020125471614747645, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 70, 'branch_depth': 5, 'trunk_width': 70, 'trunk_depth': 2, 'interact_size': 65}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  84%|██████████████████████████████████████████▊        | 42/50 [00:05<00:00,  9.25it/s][I 2025-09-07 12:59:30,788] Trial 42 finished with value: 0.02710425667464733 and parameters: {'learning_rate': 0.004919571585895916, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.GELU'>, 'branch_width': 40, 'branch_depth': 5, 'trunk_width': 70, 'trunk_depth': 2, 'interact_size': 35}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  86%|███████████████████████████████████████████▊       | 43/50 [00:05<00:00,  9.20it/s][I 2025-09-07 12:59:30,871] Trial 43 finished with value: 0.01976913772523403 and parameters: {'learning_rate': 0.0014480180230617447, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 5, 'trunk_width': 100, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:30,948] Trial 44 finished with value: 0.01947970502078533 and parameters: {'learning_rate': 0.0008147003192599334, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 100, 'branch_depth': 4, 'trunk_width': 100, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  90%|█████████████████████████████████████████████▉     | 45/50 [00:05<00:00, 10.14it/s][I 2025-09-07 12:59:31,051] Trial 45 finished with value: 0.019115528091788292 and parameters: {'learning_rate': 0.0006722383204244907, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 4, 'trunk_width': 100, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# [I 2025-09-07 12:59:31,186] Trial 46 finished with value: 0.021010007709264755 and parameters: {'learning_rate': 0.0006926289831387501, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 130, 'branch_depth': 4, 'trunk_width': 130, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  94%|███████████████████████████████████████████████▉   | 47/50 [00:05<00:00,  9.50it/s][I 2025-09-07 12:59:31,322] Trial 47 finished with value: 0.083468496799469 and parameters: {'learning_rate': 0.00022343290614862778, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 4, 'trunk_width': 100, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  96%|████████████████████████████████████████████████▉  | 48/50 [00:05<00:00,  8.98it/s][I 2025-09-07 12:59:31,452] Trial 48 finished with value: 0.02476387470960617 and parameters: {'learning_rate': 0.0004160245954147015, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.Tanh'>, 'branch_width': 100, 'branch_depth': 3, 'trunk_width': 130, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress:  98%|█████████████████████████████████████████████████▉ | 49/50 [00:05<00:00,  8.66it/s][I 2025-09-07 12:59:31,547] Trial 49 finished with value: 0.0317363403737545 and parameters: {'learning_rate': 0.00012951478553294588, 'branch_activation': <class 'torch.nn.modules.activation.Tanh'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 130, 'branch_depth': 4, 'trunk_width': 100, 'trunk_depth': 2, 'interact_size': 95}. Best is trial 0 with value: 0.01832687482237816.
# Overall Optimization Progress: 100%|███████████████████████████████████████████████████| 50/50 [00:06<00:00,  8.28it/s]
# Best parameters: {'learning_rate': 0.0008898380892557609, 'branch_activation': <class 'torch.nn.modules.activation.ReLU'>, 'trunk_activation': <class 'torch.nn.modules.activation.ReLU'>, 'branch_width': 100, 'branch_depth': 1, 'trunk_width': 130, 'trunk_depth': 2, 'interact_size': 95}

# %% [markdown]
# ## Training

# %%
import pickle
import torch
import torch.optim as optim
from torch import nn
import matplotlib.pyplot as plt
from tqdm import tqdm

# Option to load the best parameters from Optuna or perform optimization if not loaded
def load_best_params():
    try:
        with open("best_params.pkl", "rb") as f:
            best_params = pickle.load(f)
            print("Loaded best parameters from previous optimization.")
            return best_params
    except FileNotFoundError:
        print("Best parameters file not found. Running Optuna optimization.")
        study = optuna.create_study(direction="minimize")
        study.optimize(objective, n_trials=50)
        best_params = study.best_params
        with open("best_params.pkl", "wb") as f:
            pickle.dump(best_params, f)
        print("Optimized parameters saved.")
        return best_params


# Load best parameters (if available)
best_params = load_best_params()

# Print best parameters before starting training
print("Best parameters for training:")
for key, value in best_params.items():
    print(f"{key}: {value}")

# Use the best parameters to set up the model
model = DeepONet1dSep(
    in_size_branch=Xb_train.shape[1],
    interact_size=best_params["interact_size"],
    branch_width=best_params["branch_width"],
    branch_depth=best_params["branch_depth"],
    branch_activation=best_params["branch_activation"],
    trunk_input_dim=1,
    trunk_width=best_params["trunk_width"],
    trunk_depth=best_params["trunk_depth"],
    trunk_activation=best_params["trunk_activation"]
).to(device)

# Prepare data
Xb_train = torch.tensor(branch_inputs_train, dtype=torch.float32, device=device)
Xt_train = torch.tensor(trunk_inputs_train, dtype=torch.float32, device=device)
Y_train  = torch.tensor(outputs_train, dtype=torch.float32, device=device)

Xb_test = torch.tensor(branch_inputs_test, dtype=torch.float32, device=device)
Xt_test = torch.tensor(trunk_inputs_test, dtype=torch.float32, device=device)
Y_test  = torch.tensor(outputs_test, dtype=torch.float32, device=device)

# Ensure Y has shape (B, N, 1)
if Y_train.dim() == 2:
    Y_train = Y_train.unsqueeze(-1)
if Y_test.dim() == 2:
    Y_test = Y_test.unsqueeze(-1)

# Train the model
optimizer = optim.Adam(model.parameters(), lr=best_params["learning_rate"])
loss_fn = torch.nn.MSELoss()  # Use PyTorch's built-in MSELoss

loss_history = []
model.train()
num_steps = 20_000
for step in tqdm(range(num_steps)):
    optimizer.zero_grad()
    pred = model(Xb_train, Xt_train)  # (B, N, 1)
    loss = loss_fn(pred, Y_train)
    loss.backward()
    optimizer.step()
    
    loss_history.append(loss.detach().cpu().item())

# Plot the loss history after training is done
plt.plot(loss_history[100:])  # We remove the first 100 steps to better visualize the trend
plt.xlabel("Step")
plt.ylabel("MSE loss")
plt.title("Training loss")
plt.grid()
plt.show()

# Evaluate on the test set
model.eval()
with torch.no_grad():
    Y_pred = model(Xb_test, Xt_test)
    mse = torch.mean((Y_pred - Y_test)**2).item()

print(f"Test MSE: {mse:.4f}")
# Out:
# Loaded best parameters from previous optimization.
# Best parameters for training:
# learning_rate: 0.0008898380892557609
# branch_activation: <class 'torch.nn.modules.activation.ReLU'>
# trunk_activation: <class 'torch.nn.modules.activation.ReLU'>
# branch_width: 100
# branch_depth: 1
# trunk_width: 130
# trunk_depth: 2
# interact_size: 95
# 100%|███████████████████████████████████████████████████████████████████████████| 20000/20000 [03:06<00:00, 107.42it/s]
# Test MSE: 0.0000

# %% [raw]
# # Infer sizes from data
# in_size_branch = branch_inputs_train.shape[1]
# N_grid = trunk_inputs_train.shape[1]
#
# """
# model = DeepONet1d(
#     in_size_branch=in_size_branch,
#     width_size=40,
#     depth=1,
#     interact_size=40,
#     branch_activation=nn.ReLU,   # branch stays ReLU
#     trunk_activation=nn.ReLU     # trunk is smooth
# ).to(device)
# """
# #Let's try to add more hidden layers
# #TRY DIFFERENT ACTIVATION FUNCTIONS !!!!!!!!!!  -> FARE GRID SEARCH SU ARCHITETTURA
# model = DeepONet1dSep(
#     in_size_branch=in_size_branch,
#     interact_size=20,          # (p in the Lu Lu article) must match between branch & trunk outputs
#     branch_width=40,
#     branch_depth=2,
#     branch_activation=nn.Tanh, # piecewise-linear is fine for u-sensors
#     trunk_input_dim=1,
#     trunk_width=40,
#     trunk_depth=3,
#     trunk_activation=nn.Tanh   # smoother w.r.t. x
# ).to(device)
#
#
# # Torch tensors
# Xb_train = torch.tensor(branch_inputs_train, dtype=torch.float32, device=device)
# Xt_train = torch.tensor(trunk_inputs_train,  dtype=torch.float32, device=device)
# Y_train  = torch.tensor(outputs_train,       dtype=torch.float32, device=device)
#
# Xb_test = torch.tensor(branch_inputs_test, dtype=torch.float32, device=device)
# Xt_test = torch.tensor(trunk_inputs_test,  dtype=torch.float32, device=device)
# Y_test  = torch.tensor(outputs_test,       dtype=torch.float32, device=device)
#
# # Ensure Y has shape (B, N, 1)
# if Y_train.dim() == 2:
#     Y_train = Y_train.unsqueeze(-1)
# if Y_test.dim() == 2:
#     Y_test = Y_test.unsqueeze(-1)
#
#
# Xb_train.shape, Xt_train.shape, Y_train.shape, Xb_test.shape

# %% [raw]
# optimizer = optim.Adam(model.parameters(), lr=1e-3)
#
# def mse_loss(pred, target):
#     return torch.mean((pred - target) ** 2)
#
# loss_history = []
# model.train()
# num_steps = 20_000
# for _ in tqdm(range(num_steps)):
#     optimizer.zero_grad(set_to_none=True)
#     pred = model(Xb_train, Xt_train)           # (B, N, 1)
#     loss = mse_loss(pred, Y_train)
#     loss.backward()
#     optimizer.step()
#     loss_history.append(loss.detach().cpu().item())
#
# plt.plot(loss_history[100:]) #We remove the first 100 steps to better visualize the trend
# plt.xlabel("Step")
# plt.ylabel("MSE loss")
# plt.title("Training loss")
# plt.grid()
# plt.show()

# %%
#Zoom in
plt.plot(loss_history[19200:]) #We remove the first 18000 steps to better visualize the trend
plt.xlabel("Step")
plt.ylabel("MSE loss")
plt.title("Training loss")
plt.grid()
plt.show()

# %% [markdown]
# ## Test

# %%
model.eval()
with torch.no_grad():
    sample_idx = 10

    # Use shared trunk grid if Xt_test is 2D (N,1); otherwise pick sample
    if Xt_test.dim() == 2:              # (N, 1)
        xgrid_t = Xt_test               # (N, 1)
        y_pred  = model(Xb_test[sample_idx], xgrid_t)   # (N, 1)
        xgrid   = xgrid_t[:, 0].cpu().numpy()           # (N,)
    else:                                # (B, N, 1)
        xgrid_t = Xt_test[sample_idx]    # (N, 1)
        y_pred  = model(Xb_test[sample_idx], xgrid_t)   # (N, 1)
        xgrid   = xgrid_t[:, 0].cpu().numpy()           # (N,)

    # Y_test should be (B, N, 1). If it's (B, N), add the last dim.
    y_gt = Y_test[sample_idx]
    if y_gt.dim() == 1:                  # (N,) -> (N,1)
        y_gt = y_gt.unsqueeze(-1)

    plt.plot(xgrid, y_gt[:, 0].cpu().numpy(), label="gt antiderivative")
    plt.plot(xgrid, y_pred[:, 0].cpu().numpy(), label="prediction")
    plt.title("Test sample comparison")
    plt.legend()
    plt.grid()
    plt.show()

# %%
def normalized_l2_error(pred, ref):
    # pred/ref: (...,)
    diff = pred - ref
    diff_norm = torch.linalg.vector_norm(diff)
    ref_norm  = torch.linalg.vector_norm(ref)
    return (diff_norm / ref_norm).item()

model.eval()
errs = []
with torch.no_grad():
    # Batch through the whole test set
    pred = model(Xb_test, Xt_test)  # (B, N, 1)
    for b in range(pred.shape[0]):
        e = normalized_l2_error(pred[b].view(-1), Y_test[b].view(-1))
        errs.append(e)

mean_err = float(np.mean(errs))
std_err  = float(np.std(errs))
mean_err, std_err
# Out:
# (0.01927047419982652, 0.030572847655055985)

# %% [markdown]
# ## Test: predict new data

# %%
# ========= Evaluation config =========
data_path    = "antiderivative_aligned_data.npz"   # or ..._test.npz / ..._train.npz
weights_path = "deeponet.pt"                       # your saved model state_dict

"""
# Must match the trained model:
in_size_branch = 100
width_size     = 40
depth          = 1
interact_size  = 40

# What to plot
plot_sample_indices = [0, 1, 2]

# Device preference: CUDA > MPS (Apple Silicon) > CPU
import torch
if torch.cuda.is_available():
    device = torch.device("cuda")
elif getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
device
"""
# Out:
# '\n# Must match the trained model:\nin_size_branch = 100\nwidth_size     = 40\ndepth          = 1\ninteract_size  = 40\n\n# What to plot\nplot_sample_indices = [0, 1, 2]\n\n# Device preference: CUDA > MPS (Apple Silicon) > CPU\nimport torch\nif torch.cuda.is_available():\n    device = torch.device("cuda")\nelif getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():\n    device = torch.device("mps")\nelse:\n    device = torch.device("cpu")\ndevice\n'

# %%
import numpy as np

npz = np.load(data_path, allow_pickle=True)
branch_inputs = npz["X"][0]    # (B, P)
trunk_inputs  = npz["X"][1]    # (N, 1) shared grid
y_true        = npz["y"]       # (B, N) or (B, N, 1)

print("Loaded shapes:", branch_inputs.shape, trunk_inputs.shape, y_true.shape)

# Ensure y_true is (B, N, 1)
if y_true.ndim == 2:
    y_true = y_true[..., None]
elif y_true.ndim == 3 and y_true.shape[-1] == 1:
    pass
else:
    raise ValueError(f"Unexpected y shape: {y_true.shape}")

import torch
Xb = torch.tensor(branch_inputs, dtype=torch.float32, device=device)   # (B, P)
Xt = torch.tensor(trunk_inputs,  dtype=torch.float32, device=device)   # (N, 1)
Y  = torch.tensor(y_true,        dtype=torch.float32, device=device)   # (B, N, 1)

# Expand shared trunk grid to batch: (B, N, 1)
Xt_batch = Xt.unsqueeze(0).expand(Xb.shape[0], -1, -1)
# Out:
# Loaded shapes: (150, 1000) (1000, 1) (150, 1000)

# %%
print("Xb shape:", Xb.shape)         # should be (B, P) only
print("Xt shape:", Xt.shape)         # (N, 1)
try:
    print("Xt_batch shape:", Xt_batch.shape)  # (B, N, 1)
except NameError:
    pass

# What the trained model expects
branch_in_expected = model.branch_net.net[0].in_features
trunk_in_expected  = model.trunk_net.net[0].in_features
print("Model expects: branch_in =", branch_in_expected, "  trunk_in =", trunk_in_expected)

# If you previously did something like: Xb = Xb.unsqueeze(1).expand(B,N,P) — undo it.
if Xb.ndim > 2:
    # collapse any extra dims except the last one (features)
    Xb = Xb.view(Xb.shape[0], -1)  # but better: rebuild from the original branch_inputs array
    print("Fixed Xb to shape:", Xb.shape)

# Xt should be shared grid: (N,1)
# Build Xt_batch for the model call as (B,N,1), but DO NOT touch Xb
Xt_batch = Xt.unsqueeze(0).expand(Xb.shape[0], -1, -1)
print("Xt_batch shape:", Xt_batch.shape)

import numpy as np
import torch

P_data = Xb.shape[1]
P_tgt  = branch_in_expected

if P_data != P_tgt:
    # assume branch and trunk share the same interval; infer from Xt
    a = float(Xt[0,0].cpu().item())
    b = float(Xt[-1,0].cpu().item())
    x_src = np.linspace(a, b, P_data)
    x_tgt = np.linspace(a, b, P_tgt)

    Xb_np = Xb.detach().cpu().numpy()
    Xb_rs = np.stack([np.interp(x_tgt, x_src, row) for row in Xb_np], axis=0)  # (B, P_tgt)
    Xb = torch.tensor(Xb_rs, dtype=torch.float32, device=Xb.device)
    print(f"Resampled branch from P={P_data} -> P={P_tgt}")
# Out:
# Xb shape: torch.Size([150, 1000])
# Xt shape: torch.Size([1000, 1])
# Xt_batch shape: torch.Size([150, 1000, 1])
# Model expects: branch_in = 300   trunk_in = 1
# Xt_batch shape: torch.Size([150, 1000, 1])
# Resampled branch from P=1000 -> P=300

# %%
import torch

def normalized_l2_error(pred, ref):
    diff = pred - ref
    diff_norm = torch.linalg.vector_norm(diff)
    ref_norm  = torch.linalg.vector_norm(ref)
    return (diff_norm / (ref_norm + 1e-12)).item()

with torch.no_grad():
    Y_pred = model(Xb, Xt_batch)   # (B, N, 1)

B, N, _ = Y.shape
errs, mses = [], []
for i in range(B):
    errs.append(normalized_l2_error(Y_pred[i].view(-1), Y[i].view(-1)))
    mses.append(torch.mean((Y_pred[i] - Y[i])**2).item())

import numpy as np
print(f"Mean norm L2 error: {np.mean(errs):.6e}  (std {np.std(errs):.6e})")
print(f"Mean MSE:           {np.mean(mses):.6e}  (std {np.std(mses):.6e})")
# Out:
# Mean norm L2 error: 2.524843e-01  (std 1.765961e-01)
# Mean MSE:           2.315393e-04  (std 1.987530e-04)

# %%
import matplotlib.pyplot as plt

xgrid = Xt[:, 0].detach().cpu().numpy()  # (N,)

plot_sample_indices = [0, 1, 2]

for idx in plot_sample_indices:
    if not (0 <= idx < B):
        continue
    y_gt  = Y[idx, :, 0].detach().cpu().numpy()
    y_hat = Y_pred[idx, :, 0].detach().cpu().numpy()
    plt.figure()
    plt.plot(xgrid, y_gt,  label="ground truth")
    plt.plot(xgrid, y_hat, label="prediction")
    plt.title(f"Sample {idx} | normL2={errs[idx]:.3e} | MSE={mses[idx]:.3e}")
    plt.xlabel("x"); plt.ylabel("∫ u(s) ds")
    plt.grid(); plt.legend()
    plt.show()

# %% [markdown]
# ### Trial (normalization)

# %%
# ========= Evaluation config =========
data_path    = "antiderivative_aligned_data.npz"   # or ..._test.npz / ..._train.npz
weights_path = "deeponet.pt"

import numpy as np
import torch
import matplotlib.pyplot as plt

# -- Load dataset
npz = np.load(data_path, allow_pickle=True)
branch_inputs = npz["X"][0]    # (B, P)
trunk_inputs  = npz["X"][1]    # (N, 1) shared grid
y_true        = npz["y"]       # (B, N) or (B, N, 1)

print("Loaded shapes:", branch_inputs.shape, trunk_inputs.shape, y_true.shape)

# Ensure y_true has shape (B, N, 1)
if y_true.ndim == 2:
    y_true = y_true[..., None]
elif not (y_true.ndim == 3 and y_true.shape[-1] == 1):
    raise ValueError(f"Unexpected y shape: {y_true.shape}")

# ----- Normalize ONLY the input functions (branch) -----
# per-sample normalization by max|u|
eps = 1e-12
amp_branch = np.maximum(np.max(np.abs(branch_inputs), axis=1, keepdims=True), eps)  # (B,1)
branch_inputs_norm = branch_inputs / amp_branch                                    # (B,P)

# ----- Tensors -----
Xb = torch.tensor(branch_inputs_norm, dtype=torch.float32, device=device)  # normalized input (B,P)
Xt = torch.tensor(trunk_inputs,        dtype=torch.float32, device=device)  # (N,1)
Y  = torch.tensor(y_true,              dtype=torch.float32, device=device)  # ground truth (B,N,1)

# Expand shared trunk grid to batch: (B,N,1)
Xt_batch = Xt.unsqueeze(0).expand(Xb.shape[0], -1, -1)

# Resample branch if needed
branch_in_expected = model.branch_net.net[0].in_features
if Xb.shape[1] != branch_in_expected:
    a = float(Xt[0,0].detach().cpu().item())
    b = float(Xt[-1,0].detach().cpu().item())
    x_src = np.linspace(a, b, Xb.shape[1])
    x_tgt = np.linspace(a, b, branch_in_expected)
    Xb_np = Xb.detach().cpu().numpy()
    Xb_rs = np.stack([np.interp(x_tgt, x_src, row) for row in Xb_np], axis=0)  # (B, P_target)
    Xb = torch.tensor(Xb_rs, dtype=torch.float32, device=Xb.device)
    print(f"[EVAL] Resampled branch P: {Xb_np.shape[1]} -> {branch_in_expected}")

# ----- Inference (outputs are NOT normalized) -----
with torch.no_grad():
    Y_pred = model(Xb, Xt_batch)   # (B,N,1)

# ----- Metrics -----
def normalized_l2_error(pred, ref):
    diff = pred - ref
    diff_norm = torch.linalg.vector_norm(diff)
    ref_norm  = torch.linalg.vector_norm(ref)
    return (diff_norm / (ref_norm + 1e-12)).item()

B, N, _ = Y.shape
errs, mses = [], []
for i in range(B):
    errs.append(normalized_l2_error(Y_pred[i].view(-1), Y[i].view(-1)))
    mses.append(torch.mean((Y_pred[i] - Y[i])**2).item())

print(f"Mean norm L2 error: {np.mean(errs):.6e}  (std {np.std(errs):.6e})")
print(f"Mean MSE:           {np.mean(mses):.6e}  (std {np.std(mses):.6e})")

# ----- Plot -----
xgrid = Xt[:, 0].detach().cpu().numpy()
plot_sample_indices = [0, 1, 2]

for idx in plot_sample_indices:
    if not (0 <= idx < B):
        continue
    y_gt  = Y[idx, :, 0].detach().cpu().numpy()
    y_hat = Y_pred[idx, :, 0].detach().cpu().numpy()
    plt.figure()
    plt.plot(xgrid, y_gt,  label="ground truth")
    plt.plot(xgrid, y_hat, label="prediction")
    plt.title(f"Sample {idx} | normL2={errs[idx]:.3e} | MSE={mses[idx]:.3e}")
    plt.xlabel("x"); plt.ylabel("∫ u(s) ds")
    plt.grid(); plt.legend()
    plt.show()
# Out:
# Loaded shapes: (150, 1000) (1000, 1) (150, 1000)
# [EVAL] Resampled branch P: 1000 -> 300
# Mean norm L2 error: 4.324550e-01  (std 1.865200e-01)
# Mean MSE:           1.263954e-03  (std 2.019933e-03)
